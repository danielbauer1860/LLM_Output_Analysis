# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbauer1860/LDS_Project/blob/main/processing/processing_to_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook converts the generated outputs to txt-files in order to allow for easier analysis with AntConc

# %%
import pandas as pd
import numpy as np


#https://stackoverflow.com/questions/11994765/pandas-dataframe-to-string-truncating-strings-from-columns
pd.options.display.max_colwidth = 100000

# %%
df_news_2e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/2epoch-news-output.csv', sep="|")
df_news_4e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-news-output.csv', sep="|")
df_news_8e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/8epoch-news-output.csv', sep="|")

# %%
#since I did not select the correct seperator, these three dataframes require additional processing in order to extract the output
substrings = [',ACA', ',FIC', ',NEWS']

for substring in substrings:
  df_news_2e[f'output{substring}'] = df_news_2e['output,prompt_category,prompt'].apply(lambda x: x[:x.find(substring)] if substring in x else x)
df_news_2e['output'] = df_news_2e[['output,ACA', 'output,FIC', 'output,NEWS']].min(axis=1)
df_news_2e.drop(columns=['output,ACA', 'output,FIC', 'output,NEWS', 'output,prompt_category,prompt'], inplace=True)

for substring in substrings:
  df_news_4e[f'output{substring}'] = df_news_4e['output,prompt_category,prompt'].apply(lambda x: x[:x.find(substring)] if substring in x else x)
df_news_4e['output'] = df_news_4e[['output,ACA', 'output,FIC', 'output,NEWS']].min(axis=1)
df_news_4e.drop(columns=['output,ACA', 'output,FIC', 'output,NEWS', 'output,prompt_category,prompt'], inplace=True)

for substring in substrings:
  df_news_8e[f'output{substring}'] = df_news_8e['output,prompt_category,prompt'].apply(lambda x: x[:x.find(substring)] if substring in x else x)
df_news_8e['output'] = df_news_8e[['output,ACA', 'output,FIC', 'output,NEWS']].min(axis=1)
df_news_8e.drop(columns=['output,ACA', 'output,FIC', 'output,NEWS', 'output,prompt_category,prompt'], inplace=True)

# %%
df_news_8e['output'].tail()
# Out:
# 55                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Of course, I know perfectly well why the Department of the Environment declines to list it. This is because the area has been so heavily damaged by human activity that it would be impossible for any Nature Conservation Order to make a positive difference. It seems that the only thing left to do is to wait until enough natural regeneration occurs to restore the site to some sort of balance with nature.\nHowever, I was recently looking at another part of the Lower River Nith catchment which does have significant potential as an SPA, and I’m wondering whether we shouldn’t try to get this one included in our inventory too?
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Demonstrating climate to be the primary cause clears up many such problems.\nBy: Gilles-Eric Seralini, M.D., PhD | October 21, 2019\nCategories: Featured | Tags: Glyphosate, herbicide, Monsanto, Roundup\n(Photo by Kenny Louie on Unsplash)\nGlyphosate is a widely used herbicide that is notorious for its tendency to promote weed resistance and its lack of selectivity. In fact, it has been reported as one of the most dangerous pesticides due to its potential to cause cancer in humans. The International Agency for Research on Cancer (IARC), which is part of the World Health Organization (WHO), classified glyphosate as “probably carcinogenic” in 2015 based on an assessment of human studies linking glyphosate exposure with non-Hodgkin lymphoma (
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Scanner appeal co-ordinator Jack Froggatt said: ‘The town centre bombings raised awareness of the need for a scanner in Warrington and money has been coming in much quicker since then.’ It is now hoped to reach the £1m target by the autumn.\nJack added: ‘This will be a fantastic piece of equipment for our hospital, which could not only benefit local people but also those from across the North West.’\nFor more details about how you can help, visit www.warringtongeneralhospital.co.uk/appeal
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Describing the track ‘as one of the most ancient and well preserved sunken trackways in the south of England that could well pre-date Roman times,’ he said he was concerned about its ‘possible destruction’.\nHe added: “This is a site of international importance and deserves to be protected.”\nBosses at Hampshire County Council have confirmed they are now working with the Highways Agency to see if there is any way to preserve it.
# Name: output, dtype: object

# %% [markdown]
# With the `to_string` function, dataframe columns can be exported to txt

# %%
df_news_2e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/2epoch-news-output.txt', header=False, index=False, columns=['output'])
df_news_4e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-news-output.txt', header=False, index=False, columns=['output'])
df_news_8e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/8epoch-news-output.txt', header=False, index=False, columns=['output'])

# %%
df_aca_2e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/2epoch-academic-output.csv', sep="|")
df_aca_4e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-academic-output.csv', sep="|")
df_aca_8e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/8epoch-academic-output.csv', sep="|")
# Out:
#                                                output prompt_category  \
# 0   However, while shoplifting occurred in the pas...             ACA
# 1   The pressure here is to consider the sorts of ...             ACA
# 2   I was not prepared to travel 140 miles to and ...             ACA
# 3   If the interviewee is very nervous it can help...             ACA
# 4   We illustrate reduction to upper Hessenberg fo...             ACA
# 5   The arguments deployed against the reformers' ...             ACA
# 6   One idea about the life habits of the dinosaur...             ACA
# 7   It should be obvious why a single structural o...             ACA
# 8   But it always seemed to me more important from...             ACA
# 9   These are culpable acts, often regarded as bei...             ACA
# 10  In response to the e.m.f. in an electric circu...             ACA
# 11  It is not in those circumstances surprising th...             ACA
# 12  Those communities which did not receive franch...             ACA
# 13  Genesis: An Authorship Study in Computer-assis...             ACA
# 14  This view, whereby science progresses through ...             ACA
# 15  In many grammar books you will find a rule whi...             ACA
# 16  One advantage is the ability to model a range ...             ACA
# 17  A combined transformation In a recent paper, H...             ACA
# 18  The initial deformation corresponds to portion...             ACA
# 19  There is also a connection between these two, ...             ACA
# 20  ‘Well, you and Carol, you're sort of settled n...             FIC
# 21  But unemployment didn't appeal to her.\n"I'm n...             FIC
# 22  Indeed,’ Corbett stirred, staring behind the n...             FIC
# 23  There was a link, too.\nIt wasn't long before ...             FIC
# 24  "I suppose so," Sara said, a little deflated.\...             FIC
# 25  How they always wanted to know what other men ...             FIC
# 26  Let's see how you manage to be Constable with ...             FIC
# 27  They've sold American rights in both of the no...             FIC
# 28  She was overweight, overtired, distinctly anxi...             FIC
# 29  ‘But we leave tomorrow!’ she exclaimed.\n‘We d...             FIC
# 30  He was different from Owen.\nHe wasn't interes...             FIC
# 31  Wow!’ He gave her an admiring grin that was ve...             FIC
# 32  ‘The one at Porton Down has just the same safe...             FIC
# 33  ‘Or more directly, dismiss the coypu man, keep...             FIC
# 34  They all spent time covering their asses.\nTru...             FIC
# 35  Hurry up with that tea there, Maggie!\nIt’s a ...             FIC
# 36  Merely perplexing, at times.\nPosted on Septem...             FIC
# 37  And the boy he saved hasn't turned out very we...             FIC
# 38  Paula smiled, enjoying her sister's discomfort...             FIC
# 39  ‘Oh !… Oh… But I couldn't…’ ‘What is it?’ Elin...             FIC
# 40  Prayers and protest over Chernobyl From EDWARD...            NEWS
# 41  DIESELS GO INTO OVERDRIVE The glass mystery: M...            NEWS
# 42  Scanner appeal co-ordinator Jack Froggatt said...            NEWS
# 43  It's as though you put together Coriolanus, He...            NEWS
# 44  ‘I'm content to go into the army, and I'm defi...            NEWS
# 45  ‘I must stress that the involvement of armed f...            NEWS
# 46  They feared bodies would be shifted in and out...            NEWS
# 47  In fact, it was growing steadily.\nThe total n...            NEWS
# 48  Describing the track ‘as one of the most ancie...            NEWS
# 49  It is very complex, very grammatical, and the ...            NEWS
# 50  Presumably they pick up the pinta and down the...            NEWS
# 51  These organisations include the Woodland Trust...            NEWS
# 52  Questor Column: Stockpiled Ibstock Johnsen wor...            NEWS
# 53  Name badges are worn by staff.\nChildren shoul...            NEWS
# 54  Bob Kernohan would not object to being called ...            NEWS
# 55  On the contrary, they add to the pleasure of s...            NEWS
# 56  The publisher is Christopher Helm, the price £...            NEWS
# 57  The text has been cut quite wantonly and only ...            NEWS
# 58  OVERNIGHT FILE PAGE soc An opening at the Met ...            NEWS
# 59  In his comprehensive Apples Of England, Dr Tay...            NEWS
#
#                                                prompt
# 0   However, while shoplifting occurred in the pas...
# 1   The pressure here is to consider the sorts of ...
# 2   I was not prepared to travel 140 miles to and ...
# 3   If the interviewee is very nervous it can help...
# 4   We illustrate reduction to upper Hessenberg fo...
# 5   The arguments deployed against the reformers' ...
# 6   One idea about the life habits of the dinosaur...
# 7   It should be obvious why a single structural o...
# 8   But it always seemed to me more important from...
# 9   These are culpable acts, often regarded as bei...
# 10                          In response to the e.m.f.
# 11  It is not in those circumstances surprising th...
# 12  Those communities which did not receive franch...
# 13  Genesis: An Authorship Study in Computer-assis...
# 14  This view, whereby science progresses through ...
# 15  In many grammar books you will find a rule whi...
# 16  One advantage is the ability to model a range ...
# 17  A combined transformation In a recent paper, H...
# 18  The initial deformation corresponds to portion...
# 19  There is also a connection between these two, ...
# 20  ‘Well, you and Carol, you're sort of settled n...
# 21             But unemployment didn't appeal to her.
# 22  Indeed,’ Corbett stirred, staring behind the n...
# 23                             There was a link, too.
# 24      "I suppose so," Sara said, a little deflated.
# 25  How they always wanted to know what other men ...
# 26  Let's see how you manage to be Constable with ...
# 27  They've sold American rights in both of the no...
# 28  She was overweight, overtired, distinctly anxi...
# 29            ‘But we leave tomorrow!’ she exclaimed.
# 30                        He was different from Owen.
# 31  Wow!’ He gave her an admiring grin that was ve...
# 32  ‘The one at Porton Down has just the same safe...
# 33  ‘Or more directly, dismiss the coypu man, keep...
# 34          They all spent time covering their asses.
# 35              Hurry up with that tea there, Maggie!
# 36                       Merely perplexing, at times.
# 37  And the boy he saved hasn't turned out very well.
# 38  Paula smiled, enjoying her sister's discomfort...
# 39  ‘Oh !… Oh… But I couldn't…’ ‘What is it?’ Elin...
# 40  Prayers and protest over Chernobyl From EDWARD...
# 41  DIESELS GO INTO OVERDRIVE The glass mystery: M...
# 42  Scanner appeal co-ordinator Jack Froggatt said...
# 43  It's as though you put together Coriolanus, He...
# 44  ‘I'm content to go into the army, and I'm defi...
# 45  ‘I must stress that the involvement of armed f...
# 46  They feared bodies would be shifted in and out...
# 47                  In fact, it was growing steadily.
# 48  Describing the track ‘as one of the most ancie...
# 49  It is very complex, very grammatical, and the ...
# 50  Presumably they pick up the pinta and down the...
# 51  These organisations include the Woodland Trust...
# 52  Questor Column: Stockpiled Ibstock Johnsen wor...
# 53                     Name badges are worn by staff.
# 54  Bob Kernohan would not object to being called ...
# 55  On the contrary, they add to the pleasure of s...
# 56  The publisher is Christopher Helm, the price £...
# 57  The text has been cut quite wantonly and only ...
# 58  OVERNIGHT FILE PAGE soc An opening at the Met ...
# 59  In his comprehensive Apples Of England, Dr Tay...

# %%
df_aca_2e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/2epoch-academic-output.txt', header=False, index=False, columns=['output'])
df_aca_4e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-academic-output.txt', header=False, index=False, columns=['output'])
df_aca_8e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/8epoch-academic-output.txt', header=False, index=False, columns=['output'])

# %%
df_fic_2e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/2epoch-fic-output.csv', sep="|")
df_fic_4e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-fic-output.csv', sep="|")
df_fic_8e = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/8epoch-fic-output.csv', sep="|")

# %%
df_fic_2e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/2epoch-fictional-output.txt', header=False, index=False, columns=['output'])
df_fic_4e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-fictional-output.txt', header=False, index=False, columns=['output'])
df_fic_8e.to_string('/content/drive/MyDrive/Linguistic Data Science/data/8epoch-fictional-output.txt', header=False, index=False, columns=['output'])
