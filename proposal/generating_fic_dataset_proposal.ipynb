# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbauer1860/LDS_Project/blob/main/proposal/generating_fic_dataset_proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This notebook references [the project of Salminen et al. (2021)](https://github.com/joolsa/FakeReviews/blob/)

# %%
# !pip install iteround -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 tensorboard huggingface_hub[cli] xformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 43.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 52.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 41.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 44.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 54.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Loading the model

# %% [markdown]
# Redownloading the model required some tweaks, which are described in:
# https://stackoverflow.com/questions/76459034/how-to-load-a-fine-tuned-peft-lora-model-based-on-llama-with-huggingface-transfo

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoTokenizer, AutoModelForCausalLM
from accelerate import infer_auto_device_map, init_empty_weights

peft_model_id = 'dbauer1860/llama-2-bnc-baby-fictional'

config = PeftConfig.from_pretrained(peft_model_id)

model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    torch_dtype='auto',
    device_map='auto',
    offload_folder="offload", offload_state_dict = True
)
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]

# %% [markdown]
# # Extracting Word Counts and Prompts

# %%
import pandas as pd
import numpy as np
import random
import nltk
from iteround import saferound
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/bnc_baby_texts.csv', sep='|')

# %%
df.head()
# Out:
#                                                 text category
# 0    Oxford Art Journal. Sample containing about ...      ACA
# 1    The Lancet. Sample containing about 44333 wo...      ACA
# 2    Computers and the humanities. Sample contain...      ACA
# 3    British journal of social work. Sample conta...      ACA
# 4    The British polity. Sample containing about ...      ACA

# %%
def split_into_sentences(text):
    return nltk.sent_tokenize(text)

# %%
df['sentences'] = df['text'].apply(split_into_sentences)

# %%
df
# Out:
#                                                   text category  \
# 0      Oxford Art Journal. Sample containing about ...      ACA
# 1      The Lancet. Sample containing about 44333 wo...      ACA
# 2      Computers and the humanities. Sample contain...      ACA
# 3      British journal of social work. Sample conta...      ACA
# 4      The British polity. Sample containing about ...      ACA
# ..                                                 ...      ...
# 177    Liverpool Daily Post and Echo: Arts section....     NEWS
# 178    The Guardian, electronic edition of 1989-12-...     NEWS
# 179    Independent, electronic edition of 1989-10-0...     NEWS
# 180    The Scotsman: Applied Science pages. Sample ...     NEWS
# 181    Liverpool Daily Post and Echo: Leisure pages...     NEWS
#
#                                              sentences
# 0    [  Oxford Art Journal., Sample containing abou...
# 1    [  The Lancet., Sample containing about 44333 ...
# 2    [  Computers and the humanities., Sample conta...
# 3    [  British journal of social work., Sample con...
# 4    [  The British polity., Sample containing abou...
# ..                                                 ...
# 177  [  Liverpool Daily Post and Echo: Arts section...
# 178  [  The Guardian, electronic edition of 1989-12...
# 179  [  Independent, electronic edition of 1989-10-...
# 180  [  The Scotsman: Applied Science pages., Sampl...
# 181  [  Liverpool Daily Post and Echo: Leisure page...
#
# [182 rows x 3 columns]

# %%
def get_random_sentence(sentences_list, random_state=1860, min_word_count=5):
    random.seed(random_state)
    filtered_sentences = [sentence for sentence in sentences_list if len(word_tokenize(sentence)) > min_word_count]
    return random.choice(filtered_sentences) if filtered_sentences else None

# %%
df['prompt'] = df['sentences'].apply(get_random_sentence)

# %%
def get_samples(df, n=10, state=1860):
  return df.sample(n=n, random_state=state)

# %%
df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]
# Out:
# <ipython-input-15-c993aa370679>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]

# %%
df_news
# Out:
#                                                   text category  \
# 93     The Guardian, electronic edition of 1989-12-...     NEWS
# 179    Independent, electronic edition of 1989-10-0...     NEWS
# 96     Independent, electronic edition of 1989-10-0...     NEWS
# 99     Liverpool Daily Post and Echo: Applied Scien...     NEWS
# 181    Liverpool Daily Post and Echo: Leisure pages...     NEWS
# 159    Independent, electronic edition of 1989-10-1...     NEWS
# 94     Independent, electronic edition of 1989-10-0...     NEWS
# 171    Independent, electronic edition of 1989-10-0...     NEWS
# 136    The Guardian, electronic edition of 1989-11-...     NEWS
# 108    Northern Echo: Arts section. Sample containi...     NEWS
#
#                                              sentences  \
# 93   [  The Guardian, electronic edition of 1989-12...
# 179  [  Independent, electronic edition of 1989-10-...
# 96   [  Independent, electronic edition of 1989-10-...
# 99   [  Liverpool Daily Post and Echo: Applied Scie...
# 181  [  Liverpool Daily Post and Echo: Leisure page...
# 159  [  Independent, electronic edition of 1989-10-...
# 94   [  Independent, electronic edition of 1989-10-...
# 171  [  Independent, electronic edition of 1989-10-...
# 136  [  The Guardian, electronic edition of 1989-11...
# 108  [  Northern Echo: Arts section., Sample contai...
#
#                                                 prompt
# 93    ’ \n The  Joint  Command  began  taking  risks .
# 179  It  has  become  increasingly  apparent  that ...
# 96   If  the  builder  is  employed  by  an  archit...
# 99   ’ \n In  the  meantime ,  the  tendering  proc...
# 181  I 'll  fight  on  —  Foreman \n GEORGE  FOREMA...
# 159  The  awkward  changes  of  tone  caused  by  t...
# 94   Keeping  the  fabric  of  history :  Taking  c...
# 171  Sculpted  from  white  plaster  like  the  stu...
# 136  ’ \n With  the  backing  of  the  BBC ,  the  ...
# 108  In  the  finale  the  abrupt  changes  of  pac...

# %%
aca_prompts = df_aca['prompt'].to_list()
fic_prompts = df_fic['prompt'].to_list()
news_prompts = df_news['prompt'].to_list()

# %% [markdown]
# # Generating output

# %%
#Generation parameters; these were, for the most part, set in accordance to Salminen et al.
#the only difference is the implementation of a deviation value
do_sample = True
top_k = 0
top_p = 0.92
temperature = 0.7
eos_token = model.config.eos_token_id
device = "cuda:0"
deviation = 5

# %%
#from Salminen et al.; a seed value was set to allow the generation to be re-produced and continued over multiple sessions
def random_seed(seed_value, use_cuda):
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    random.seed(seed_value) # Python
    if use_cuda:
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# The generating loop

# %%
def generate(prompts):
  outputs = []
  for prompt in prompts:
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    random_seed(seed_value=1860, use_cuda=True)
    o = model.generate(**inputs, do_sample=do_sample, top_k=top_k, top_p=top_p, temperature=temperature, eos_token_id=eos_token, max_length=500)
    outputs.append(tokenizer.decode(o[0], skip_special_tokens=True))
  return outputs

# %%
aca_outputs = generate(aca_prompts)

# %%
fic_outputs = generate(fic_prompts)

# %%
news_outputs = generate(news_prompts)

# %%
aca_results = pd.DataFrame(aca_outputs, columns=['output'])
aca_results['prompt_category'] = 'ACA'
aca_results['prompt'] = aca_prompts

fic_results = pd.DataFrame(fic_outputs, columns=['output'])
fic_results['prompt_category'] = 'FIC'
fic_results['prompt'] = fic_prompts

news_results = pd.DataFrame(news_outputs, columns=['output'])
news_results['prompt_category'] = 'NEWS'
news_results['prompt'] = news_prompts

result_frames = [aca_results, fic_results, news_results]

result_df = pd.concat(result_frames, ignore_index=True)
result_df
# Out:
#                                                output prompt_category  \
# 0   These  conditions  typically  exist  in  garag...             ACA
# 1   The  irony  of  this  lay  in  the  fact  that...             ACA
# 2   I  arranged  to  visit  that  afternoon  and  ...             ACA
# 3   The  dissemination  of  information  in  the  ...             ACA
# 4   Even  if  a  species  somehow  managed  to  be...             ACA
# 5   The  woody  monocotyledon ,  Cordylinefruticos...             ACA
# 6   In  the  cytogenetic  study  only  3  metaphas...             ACA
# 7   The  posture  of  many  dinosaurs ,  and  part...             ACA
# 8   At  a  recent  meeting  of  the  North  West  ...             ACA
# 9   10  Conclusion \n I  have  stressed  that  I  ...             ACA
# 10  Now  he  was  out  of  his  Richie  Quick  fug...             FIC
# 11  ‘ Was  Marcus  with  you ? '\n' No, he was not...             FIC
# 12  Come   up ,  black  dada/nihilismus .\nIt is a...             FIC
# 13  ’ \n As  she  was  about  to  hand  a  cup  to...             FIC
# 14  ’ \n ‘ The  word  ‘ autopsy ’  kept  running  ...             FIC
# 15  ’ \n ‘ How  could  you  have  known ?’\n\nThe ...             FIC
# 16  He  was  grim-faced  and  looked  as  if  he  ...             FIC
# 17  Even  mother  —  even  mother  —  I  now  real...             FIC
# 18  ‘ What  are  you  wearing  to  the  youth  clu...             FIC
# 19  He  was  a  man  who  had  started  out  in  h...             FIC
# 20  ’ \n The  Joint  Command  began  taking  risks...            NEWS
# 21  It  has  become  increasingly  apparent  that ...            NEWS
# 22  If  the  builder  is  employed  by  an  archit...            NEWS
# 23  ’ \n In  the  meantime ,  the  tendering  proc...            NEWS
# 24  I 'll  fight  on  —  Foreman \n GEORGE  FOREMA...            NEWS
# 25  The  awkward  changes  of  tone  caused  by  t...            NEWS
# 26  Keeping  the  fabric  of  history :  Taking  c...            NEWS
# 27  Sculpted  from  white  plaster  like  the  stu...            NEWS
# 28  ’ \n With  the  backing  of  the  BBC ,  the  ...            NEWS
# 29  In  the  finale  the  abrupt  changes  of  pac...            NEWS
#
#                                                prompt
# 0   These  conditions  typically  exist  in  garag...
# 1   The  irony  of  this  lay  in  the  fact  that...
# 2   I  arranged  to  visit  that  afternoon  and  ...
# 3   The  dissemination  of  information  in  the  ...
# 4   Even  if  a  species  somehow  managed  to  be...
# 5   The  woody  monocotyledon ,  Cordylinefruticos...
# 6   In  the  cytogenetic  study  only  3  metaphas...
# 7   The  posture  of  many  dinosaurs ,  and  part...
# 8   At  a  recent  meeting  of  the  North  West  ...
# 9   10  Conclusion \n I  have  stressed  that  I  ...
# 10  Now  he  was  out  of  his  Richie  Quick  fug...
# 11                         ‘ Was  Marcus  with  you ?
# 12              Come   up ,  black  dada/nihilismus .
# 13  ’ \n As  she  was  about  to  hand  a  cup  to...
# 14  ’ \n ‘ The  word  ‘ autopsy ’  kept  running  ...
# 15              ’ \n ‘ How  could  you  have  known ?
# 16  He  was  grim-faced  and  looked  as  if  he  ...
# 17  Even  mother  —  even  mother  —  I  now  real...
# 18  ‘ What  are  you  wearing  to  the  youth  clu...
# 19  He  was  a  man  who  had  started  out  in  h...
# 20   ’ \n The  Joint  Command  began  taking  risks .
# 21  It  has  become  increasingly  apparent  that ...
# 22  If  the  builder  is  employed  by  an  archit...
# 23  ’ \n In  the  meantime ,  the  tendering  proc...
# 24  I 'll  fight  on  —  Foreman \n GEORGE  FOREMA...
# 25  The  awkward  changes  of  tone  caused  by  t...
# 26  Keeping  the  fabric  of  history :  Taking  c...
# 27  Sculpted  from  white  plaster  like  the  stu...
# 28  ’ \n With  the  backing  of  the  BBC ,  the  ...
# 29  In  the  finale  the  abrupt  changes  of  pac...

# %%
result_df.to_csv('/content/drive/MyDrive/Linguistic Data Science/data/llama-2-fictional-output.csv', index=False)
