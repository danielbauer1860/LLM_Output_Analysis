# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbauer1860/LDS_Project/blob/main/generation/generating_news_8epoch_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This notebook references [the project of Salminen et al. (2021)](https://github.com/joolsa/FakeReviews/blob/)

# %%
# !pip install iteround -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 tensorboard huggingface_hub[cli] xformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 88.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 31.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 46.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 39.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 62.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.3 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Loading the model

# %% [markdown]
# Redownloading the model required some tweaks, which are described in:
# https://stackoverflow.com/questions/76459034/how-to-load-a-fine-tuned-peft-lora-model-based-on-llama-with-huggingface-transfo

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoTokenizer, AutoModelForCausalLM
from accelerate import infer_auto_device_map, init_empty_weights

peft_model_id = 'dbauer1860/llama-2-bnc-baby-news-8-epochs'

config = PeftConfig.from_pretrained(peft_model_id)

model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    torch_dtype='auto',
    device_map='auto',
    offload_folder="offload", offload_state_dict = True
)
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]

# %% [markdown]
# # Extracting Word Counts and Prompts

# %%
import pandas as pd
import numpy as np
import random
import nltk
from iteround import saferound
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/bnc_baby_texts.csv', sep='|')

# %%
df.head()
# Out:
#                                                 text category
# 0  Why do certain images matter to one, and why i...      ACA
# 1  In many developing countries, the immunogenici...      ACA
# 2  Anthony Kenny The British Library 1992 Scholar...      ACA
# 3  Beforehand he worked as a probation officer fo...      ACA
# 4  CONTINUITY AND CHANGE are features of every po...      ACA

# %%
def split_into_sentences(text):
    return nltk.sent_tokenize(text)

# %%
df['sentences'] = df['text'].apply(split_into_sentences)

# %%
df
# Out:
#                                                   text category  \
# 0    Why do certain images matter to one, and why i...      ACA
# 1    In many developing countries, the immunogenici...      ACA
# 2    Anthony Kenny The British Library 1992 Scholar...      ACA
# 3    Beforehand he worked as a probation officer fo...      ACA
# 4    CONTINUITY AND CHANGE are features of every po...      ACA
# ..                                                 ...      ...
# 177  Artworks THE Friends of Oriel Ynys Mon, Llange...     NEWS
# 178  THERE will be those who portray the report of ...     NEWS
# 179  BUCKINGHAM PALACE 30 September: The Princess R...     NEWS
# 180  The Scottish Landowners' Federation unequivoca...     NEWS
# 181  An under-16s ladies soccer meeting will be hel...     NEWS
#
#                                              sentences
# 0    [Why do certain images matter to one, and why ...
# 1    [In many developing countries, the immunogenic...
# 2    [Anthony Kenny The British Library 1992 Schola...
# 3    [Beforehand he worked as a probation officer f...
# 4    [CONTINUITY AND CHANGE are features of every p...
# ..                                                 ...
# 177  [Artworks THE Friends of Oriel Ynys Mon, Llang...
# 178  [THERE will be those who portray the report of...
# 179  [BUCKINGHAM PALACE 30 September: The Princess ...
# 180  [The Scottish Landowners' Federation unequivoc...
# 181  [An under-16s ladies soccer meeting will be he...
#
# [182 rows x 3 columns]

# %%
random_state = 38
random_sentence_state = 1860
sample_count = 20

# %%
def get_random_sentence(sentences_list, random_state=random_sentence_state, min_word_count=5):
    random.seed(random_state)
    filtered_sentences = [sentence for sentence in sentences_list if len(word_tokenize(sentence)) > min_word_count]
    return random.choice(filtered_sentences) if filtered_sentences else None

# %%
df['prompt'] = df['sentences'].apply(get_random_sentence)

# %%
def get_samples(df, n=sample_count, state=random_state):
  return df.sample(n=n, random_state=state)

# %%
df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]
# Out:
# <ipython-input-16-c993aa370679>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]

# %%
df_news
# Out:
#                                                   text category  \
# 125  IT SEEMS that Roland Franklin, the latest unbu...     NEWS
# 143  HUNCHED over something very similar to the con...     NEWS
# 133  PCBs — polychlorinated biphenyls — are very in...     NEWS
# 129  THE couch cavorted upon by Joanne Whalley-Kilm...     NEWS
# 148  But the new production at the Royal Shakespear...     NEWS
# 101  BARRISTERS could retain much of their monopoly...     NEWS
# 139  The team, yet to be named in full, will play t...     NEWS
# 102  ‘Bucephala clangula’ sounds noisy but, in fact...     NEWS
# 155  They were attacked after the bear broke free f...     NEWS
# 172  Sunbed scare… Could this machine damage your h...     NEWS
# 170  The half-year course begins next month and off...     NEWS
# 90   GOVERNMENT spending cuts in the fight against ...     NEWS
# 157  THE POPE has told Roman Catholic priests they ...     NEWS
# 161  The disaster was all the more stunning because...     NEWS
# 93   During the 1970s Andres Valenzuela, right, ser...     NEWS
# 107  BIRMINGHAM'S infamous and exhausted retail hub...     NEWS
# 130  THE information technology revolution has left...     NEWS
# 123  West led the queen of clubs, and declarer won ...     NEWS
# 99   Vauxhall announced on May 28 that all 5,128 of...     NEWS
# 120  Now the angry owner, whose home has been burgl...     NEWS
#
#                                              sentences  \
# 125  [IT SEEMS that Roland Franklin, the latest unb...
# 143  [HUNCHED over something very similar to the co...
# 133  [PCBs — polychlorinated biphenyls — are very i...
# 129  [THE couch cavorted upon by Joanne Whalley-Kil...
# 148  [But the new production at the Royal Shakespea...
# 101  [BARRISTERS could retain much of their monopol...
# 139  [The team, yet to be named in full, will play ...
# 102  [‘Bucephala clangula’ sounds noisy but, in fac...
# 155  [They were attacked after the bear broke free ...
# 172  [Sunbed scare… Could this machine damage your ...
# 170  [The half-year course begins next month and of...
# 90   [GOVERNMENT spending cuts in the fight against...
# 157  [THE POPE has told Roman Catholic priests they...
# 161  [The disaster was all the more stunning becaus...
# 93   [During the 1970s Andres Valenzuela, right, se...
# 107  [BIRMINGHAM'S infamous and exhausted retail hu...
# 130  [THE information technology revolution has lef...
# 123  [West led the queen of clubs, and declarer won...
# 99   [Vauxhall announced on May 28 that all 5,128 o...
# 120  [Now the angry owner, whose home has been burg...
#
#                                                 prompt
# 125  This is hardly the sort of catchy title guaran...
# 143  After protecting herself during her travelling...
# 133  Less determined countries export their waste a...
# 129  They begged Rytasha for reimbursement, but non...
# 148  It's as though you put together Coriolanus, He...
# 101  The Satanic Verses referred to Mrs Thatcher as...
# 139  Today Toyota are pinning their hopes on Phil S...
# 102  Mistletoe was once quite common — as were appl...
# 155                     A Sherpa also broke his ankle.
# 172  More than 500 staff and 450 GPs who are believ...
# 170  DIESELS GO INTO OVERDRIVE The glass mystery: M...
# 90   Her first career as a hairdresser no longer ap...
# 157  A Hamish Hamilton spokeswoman said the book wo...
# 161  ‘I must stress that the involvement of armed f...
# 93            Not all the interrogators were veterans.
# 107  Of course, I know perfectly well why the Depar...
# 130  Demonstrating climate to be the primary cause ...
# 123  The reason behind this concentrated specialist...
# 99   Scanner appeal co-ordinator Jack Froggatt said...
# 120  Describing the track ‘as one of the most ancie...

# %%
aca_prompts = df_aca['prompt'].to_list()
fic_prompts = df_fic['prompt'].to_list()
news_prompts = df_news['prompt'].to_list()

# %% [markdown]
# # Generating output

# %%
#Generation parameters; these were, for the most part, set in accordance to Salminen et al.
#the only difference is the implementation of a deviation value
do_sample = True
top_k = 0
top_p = 0.92
temperature = 0.7
eos_token = model.config.eos_token_id
device = "cuda:0"
max_length = 1000
repetition_penalty = 1.1

# %%
#from Salminen et al.; a seed value was set to allow the generation to be re-produced and continued over multiple sessions
def random_seed(seed_value, use_cuda):
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    random.seed(seed_value) # Python
    if use_cuda:
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# The generating loop

# %%
def generate(prompts):
  outputs = []
  for prompt in prompts:
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    random_seed(seed_value=random_state, use_cuda=True)
    o = model.generate(**inputs, do_sample=do_sample, top_k=top_k, top_p=top_p, temperature=temperature, eos_token_id=eos_token, max_length=max_length, repetition_penalty=repetition_penalty)
    outputs.append(tokenizer.decode(o[0], skip_special_tokens=True))
  return outputs

# %%
aca_outputs = generate(aca_prompts)

# %%
fic_outputs = generate(fic_prompts)

# %%
news_outputs = generate(news_prompts)

# %%
aca_results = pd.DataFrame(aca_outputs, columns=['output'])
aca_results['prompt_category'] = 'ACA'
aca_results['prompt'] = aca_prompts

fic_results = pd.DataFrame(fic_outputs, columns=['output'])
fic_results['prompt_category'] = 'FIC'
fic_results['prompt'] = fic_prompts

news_results = pd.DataFrame(news_outputs, columns=['output'])
news_results['prompt_category'] = 'NEWS'
news_results['prompt'] = news_prompts

result_frames = [aca_results, fic_results, news_results]

result_df = pd.concat(result_frames, ignore_index=True)
result_df
# Out:
#                                                output prompt_category  \
# 0   Blocking will not usually increase the probabi...             ACA
# 1   A combined transformation In a recent paper, H...             ACA
# 2   Conclusions: Policy Rhetoric and Structural Re...             ACA
# 3   Apart from Wollen's historical and theoretical...             ACA
# 4   This much is social  democratic orthodoxy. It ...             ACA
# 5   The initial deformation corresponds to portion...             ACA
# 6   It is the same — and we should not be surprise...             ACA
# 7   But it always seemed to me more important from...             ACA
# 8   However, while shoplifting occurred in the pas...             ACA
# 9   It should be obvious why a single structural o...             ACA
# 10  It is not in those circumstances surprising th...             ACA
# 11  One advantage is the ability to model a range ...             ACA
# 12  One idea about the life habits of the dinosaur...             ACA
# 13  This view, whereby science progresses through ...             ACA
# 14  There is also a connection between these two, ...             ACA
# 15  No doubt a finder of perishable commodities wo...             ACA
# 16  In response to the e.m.f. force, the particles...             ACA
# 17  The effects of humans can go far beyond this, ...             ACA
# 18  Its significance lies in the seriousness of th...             ACA
# 19  We illustrate reduction to upper Hessenberg fo...             ACA
# 20  They all spent time covering their asses. They...             FIC
# 21  Paula smiled, enjoying her sister's discomfort...             FIC
# 22  ‘Or more directly, dismiss the coypu man, keep...             FIC
# 23  ‘Oh no,’ he said. ‘I can’t take you to the dan...             FIC
# 24  Indeed,’ Corbett stirred, staring behind the n...             FIC
# 25  They've sold American rights in both of the no...             FIC
# 26  Let's see how you manage to be Constable with ...             FIC
# 27  The other was from the Vice President in charg...             FIC
# 28  Crowe and Anthea Warburton lay parallel, Anthe...             FIC
# 29  ‘But we leave tomorrow!’ she exclaimed. ‘I can...             FIC
# 30  He was different from Owen.\nHe was a strange ...             FIC
# 31  ‘Oh !… Oh… But I couldn't…’ ‘What is it?’ Elin...             FIC
# 32  Everywhere I hear about the malaise and uncert...             FIC
# 33  How they always wanted to know what other men ...             FIC
# 34  ‘The one at Porton Down has just the same safe...             FIC
# 35  Merely perplexing, at times.\nBy: Alyssa Colla...             FIC
# 36  ‘Well, you and Carol, you're sort of settled n...             FIC
# 37  Hurry up with that tea there, Maggie!\nBy Leig...             FIC
# 38  She was overweight, overtired, distinctly anxi...             FIC
# 39  Wow!’ He gave her an admiring grin that was ve...             FIC
# 40  This is hardly the sort of catchy title guaran...            NEWS
# 41  After protecting herself during her travelling...            NEWS
# 42  Less determined countries export their waste a...            NEWS
# 43  They begged Rytasha for reimbursement, but non...            NEWS
# 44  It's as though you put together Coriolanus, He...            NEWS
# 45  The Satanic Verses referred to Mrs Thatcher as...            NEWS
# 46  Today Toyota are pinning their hopes on Phil S...            NEWS
# 47  Mistletoe was once quite common — as were appl...            NEWS
# 48  A Sherpa also broke his ankle.\nBy: Agencies |...            NEWS
# 49  More than 500 staff and 450 GPs who are believ...            NEWS
# 50  DIESELS GO INTO OVERDRIVE The glass mystery: M...            NEWS
# 51  Her first career as a hairdresser no longer ap...            NEWS
# 52  A Hamish Hamilton spokeswoman said the book wo...            NEWS
# 53  ‘I must stress that the involvement of armed f...            NEWS
# 54  Not all the interrogators were veterans. They ...            NEWS
# 55  Of course, I know perfectly well why the Depar...            NEWS
# 56  Demonstrating climate to be the primary cause ...            NEWS
# 57  The reason behind this concentrated specialist...            NEWS
# 58  Scanner appeal co-ordinator Jack Froggatt said...            NEWS
# 59  Describing the track ‘as one of the most ancie...            NEWS
#
#                                                prompt
# 0   Blocking will not usually increase the probabi...
# 1   A combined transformation In a recent paper, H...
# 2   Conclusions: Policy Rhetoric and Structural Re...
# 3   Apart from Wollen's historical and theoretical...
# 4          This much is social  democratic orthodoxy.
# 5   The initial deformation corresponds to portion...
# 6   It is the same — and we should not be surprise...
# 7   But it always seemed to me more important from...
# 8   However, while shoplifting occurred in the pas...
# 9   It should be obvious why a single structural o...
# 10  It is not in those circumstances surprising th...
# 11  One advantage is the ability to model a range ...
# 12  One idea about the life habits of the dinosaur...
# 13  This view, whereby science progresses through ...
# 14  There is also a connection between these two, ...
# 15  No doubt a finder of perishable commodities wo...
# 16                          In response to the e.m.f.
# 17  The effects of humans can go far beyond this, ...
# 18  Its significance lies in the seriousness of th...
# 19  We illustrate reduction to upper Hessenberg fo...
# 20          They all spent time covering their asses.
# 21  Paula smiled, enjoying her sister's discomfort...
# 22  ‘Or more directly, dismiss the coypu man, keep...
# 23                                  ‘Oh no,’ he said.
# 24  Indeed,’ Corbett stirred, staring behind the n...
# 25  They've sold American rights in both of the no...
# 26  Let's see how you manage to be Constable with ...
# 27  The other was from the Vice President in charg...
# 28  Crowe and Anthea Warburton lay parallel, Anthe...
# 29            ‘But we leave tomorrow!’ she exclaimed.
# 30                        He was different from Owen.
# 31  ‘Oh !… Oh… But I couldn't…’ ‘What is it?’ Elin...
# 32  Everywhere I hear about the malaise and uncert...
# 33  How they always wanted to know what other men ...
# 34  ‘The one at Porton Down has just the same safe...
# 35                       Merely perplexing, at times.
# 36  ‘Well, you and Carol, you're sort of settled n...
# 37              Hurry up with that tea there, Maggie!
# 38  She was overweight, overtired, distinctly anxi...
# 39  Wow!’ He gave her an admiring grin that was ve...
# 40  This is hardly the sort of catchy title guaran...
# 41  After protecting herself during her travelling...
# 42  Less determined countries export their waste a...
# 43  They begged Rytasha for reimbursement, but non...
# 44  It's as though you put together Coriolanus, He...
# 45  The Satanic Verses referred to Mrs Thatcher as...
# 46  Today Toyota are pinning their hopes on Phil S...
# 47  Mistletoe was once quite common — as were appl...
# 48                     A Sherpa also broke his ankle.
# 49  More than 500 staff and 450 GPs who are believ...
# 50  DIESELS GO INTO OVERDRIVE The glass mystery: M...
# 51  Her first career as a hairdresser no longer ap...
# 52  A Hamish Hamilton spokeswoman said the book wo...
# 53  ‘I must stress that the involvement of armed f...
# 54           Not all the interrogators were veterans.
# 55  Of course, I know perfectly well why the Depar...
# 56  Demonstrating climate to be the primary cause ...
# 57  The reason behind this concentrated specialist...
# 58  Scanner appeal co-ordinator Jack Froggatt said...
# 59  Describing the track ‘as one of the most ancie...

# %%
result_df.to_csv('/content/drive/MyDrive/Linguistic Data Science/data/8epoch-news-output.csv', index=False)
