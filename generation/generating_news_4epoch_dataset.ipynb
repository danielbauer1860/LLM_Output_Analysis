# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbauer1860/LDS_Project/blob/main/generation/generating_news_4epoch_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This notebook references [the project of Salminen et al. (2021)](https://github.com/joolsa/FakeReviews/blob/)

# %%
# !pip install iteround -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 tensorboard huggingface_hub[cli] xformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 41.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 66.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 63.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 89.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 53.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.7 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Loading the model

# %% [markdown]
# Redownloading the model required some tweaks, which are described in:
# https://stackoverflow.com/questions/76459034/how-to-load-a-fine-tuned-peft-lora-model-based-on-llama-with-huggingface-transfo

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoTokenizer, AutoModelForCausalLM
from accelerate import infer_auto_device_map, init_empty_weights

peft_model_id = 'dbauer1860/llama-2-bnc-baby-news-4-epochs'

config = PeftConfig.from_pretrained(peft_model_id)

model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    torch_dtype='auto',
    device_map='auto',
    offload_folder="offload", offload_state_dict = True
)
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]

# %% [markdown]
# # Extracting Word Counts and Prompts

# %%
import pandas as pd
import numpy as np
import random
import nltk
from iteround import saferound
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/bnc_baby_texts.csv', sep='|')

# %%
df.head()
# Out:
#                                                 text category
# 0  Why do certain images matter to one, and why i...      ACA
# 1  In many developing countries, the immunogenici...      ACA
# 2  Anthony Kenny The British Library 1992 Scholar...      ACA
# 3  Beforehand he worked as a probation officer fo...      ACA
# 4  CONTINUITY AND CHANGE are features of every po...      ACA

# %%
def split_into_sentences(text):
    return nltk.sent_tokenize(text)

# %%
df['sentences'] = df['text'].apply(split_into_sentences)

# %%
df
# Out:
#                                                   text category  \
# 0    Why do certain images matter to one, and why i...      ACA
# 1    In many developing countries, the immunogenici...      ACA
# 2    Anthony Kenny The British Library 1992 Scholar...      ACA
# 3    Beforehand he worked as a probation officer fo...      ACA
# 4    CONTINUITY AND CHANGE are features of every po...      ACA
# ..                                                 ...      ...
# 177  Artworks THE Friends of Oriel Ynys Mon, Llange...     NEWS
# 178  THERE will be those who portray the report of ...     NEWS
# 179  BUCKINGHAM PALACE 30 September: The Princess R...     NEWS
# 180  The Scottish Landowners' Federation unequivoca...     NEWS
# 181  An under-16s ladies soccer meeting will be hel...     NEWS
#
#                                              sentences
# 0    [Why do certain images matter to one, and why ...
# 1    [In many developing countries, the immunogenic...
# 2    [Anthony Kenny The British Library 1992 Schola...
# 3    [Beforehand he worked as a probation officer f...
# 4    [CONTINUITY AND CHANGE are features of every p...
# ..                                                 ...
# 177  [Artworks THE Friends of Oriel Ynys Mon, Llang...
# 178  [THERE will be those who portray the report of...
# 179  [BUCKINGHAM PALACE 30 September: The Princess ...
# 180  [The Scottish Landowners' Federation unequivoc...
# 181  [An under-16s ladies soccer meeting will be he...
#
# [182 rows x 3 columns]

# %%
random_state = 34
random_sentence_state = 1860
sample_count = 20

# %%
def get_random_sentence(sentences_list, random_state=random_sentence_state, min_word_count=5):
    random.seed(random_state)
    filtered_sentences = [sentence for sentence in sentences_list if len(word_tokenize(sentence)) > min_word_count]
    return random.choice(filtered_sentences) if filtered_sentences else None

# %%
df['prompt'] = df['sentences'].apply(get_random_sentence)

# %%
def get_samples(df, n=sample_count, state=random_state):
  return df.sample(n=n, random_state=state)

# %%
df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]
# Out:
# <ipython-input-16-c993aa370679>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]

# %%
df_news
# Out:
#                                                   text category  \
# 100  HELP the Aged's shops are warming up for winte...     NEWS
# 109  IF THIS WAS HAPPINESS by Barbara Leaming, Weid...     NEWS
# 95   This week's figures suggest that one in three ...     NEWS
# 181  An under-16s ladies soccer meeting will be hel...     NEWS
# 113  ELAINE HEATH likes pink eye glitter and a vodk...     NEWS
# 126  GEOFF Mulcahy, the soft-spoken chief executive...     NEWS
# 89   WILD BOAR once roamed the fields and forests o...     NEWS
# 177  Artworks THE Friends of Oriel Ynys Mon, Llange...     NEWS
# 175  MORE than 5,000 workers have swamped Hamilton ...     NEWS
# 146  PERHAPS the Independent Traveller ought to car...     NEWS
# 178  THERE will be those who portray the report of ...     NEWS
# 117  Mrs Iris Marr, prosecuting, told the court Rob...     NEWS
# 124  Morning sickness good for mothers By Roger Hig...     NEWS
# 99   Vauxhall announced on May 28 that all 5,128 of...     NEWS
# 160  Interim figures unveiled yesterday show a 16% ...     NEWS
# 173  The patient (Uma Thurman) seems to have underg...     NEWS
# 166  THE Conservatives sought last night to force t...     NEWS
# 107  BIRMINGHAM'S infamous and exhausted retail hub...     NEWS
# 142  The 18-year-old from North Shields beat off ei...     NEWS
# 145  And a health board inquiry centring on several...     NEWS
#
#                                              sentences  \
# 100  [HELP the Aged's shops are warming up for wint...
# 109  [IF THIS WAS HAPPINESS by Barbara Leaming, Wei...
# 95   [This week's figures suggest that one in three...
# 181  [An under-16s ladies soccer meeting will be he...
# 113  [ELAINE HEATH likes pink eye glitter and a vod...
# 126  [GEOFF Mulcahy, the soft-spoken chief executiv...
# 89   [WILD BOAR once roamed the fields and forests ...
# 177  [Artworks THE Friends of Oriel Ynys Mon, Llang...
# 175  [MORE than 5,000 workers have swamped Hamilton...
# 146  [PERHAPS the Independent Traveller ought to ca...
# 178  [THERE will be those who portray the report of...
# 117  [Mrs Iris Marr, prosecuting, told the court Ro...
# 124  [Morning sickness good for mothers By Roger Hi...
# 99   [Vauxhall announced on May 28 that all 5,128 o...
# 160  [Interim figures unveiled yesterday show a 16%...
# 173  [The patient (Uma Thurman) seems to have under...
# 166  [THE Conservatives sought last night to force ...
# 107  [BIRMINGHAM'S infamous and exhausted retail hu...
# 142  [The 18-year-old from North Shields beat off e...
# 145  [And a health board inquiry centring on severa...
#
#                                                 prompt
# 100  Mrs Cross flew back to Manchester yesterday to...
# 109  Realising that she had not loved him, Boris th...
# 95   TRIPS to Ireland recently have reinforced my v...
# 181  Llanidloes finished on 127–9, in which Sean So...
# 113  But it is essentially up to the patient.’ He s...
# 126         Hammerson shot up 45p to 855p in sympathy.
# 89   As Fazzi Brothers is to Glasgow and the west o...
# 177  Nasty man takes revenge, but stabs Lisa by mis...
# 175  The discounts include 3pc off the standard loa...
# 146  Eating Out: Plenty of places in all price rang...
# 178  Accountants Touche Ross asked for an extension...
# 117  In the coming year, he expects to borrow £50,0...
# 124  These organisations include the Woodland Trust...
# 99   Scanner appeal co-ordinator Jack Froggatt said...
# 160  The shares plunged 18p to 266p on news that pr...
# 173  The Picassos, according to Sotheby's valuer, w...
# 166  Mr Hurd said delays in granting exit visas to ...
# 107  Of course, I know perfectly well why the Depar...
# 142  Jason, born eight minutes before his brother, ...
# 145  ‘The people who are failing miserably are the ...

# %%
aca_prompts = df_aca['prompt'].to_list()
fic_prompts = df_fic['prompt'].to_list()
news_prompts = df_news['prompt'].to_list()

# %% [markdown]
# # Generating output

# %%
#Generation parameters; these were, for the most part, set in accordance to Salminen et al.
#the only difference is the implementation of a deviation value
do_sample = True
top_k = 0
top_p = 0.92
temperature = 0.7
eos_token = model.config.eos_token_id
device = "cuda:0"
max_length = 1000
repetition_penalty = 1.1

# %%
#from Salminen et al.; a seed value was set to allow the generation to be re-produced and continued over multiple sessions
def random_seed(seed_value, use_cuda):
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    random.seed(seed_value) # Python
    if use_cuda:
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# The generating loop

# %%
def generate(prompts):
  outputs = []
  for prompt in prompts:
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    random_seed(seed_value=random_state, use_cuda=True)
    o = model.generate(**inputs, do_sample=do_sample, top_k=top_k, top_p=top_p, temperature=temperature, eos_token_id=eos_token, max_length=max_length, repetition_penalty=repetition_penalty)
    outputs.append(tokenizer.decode(o[0], skip_special_tokens=True))
  return outputs

# %%
aca_outputs = generate(aca_prompts)

# %%
fic_outputs = generate(fic_prompts)

# %%
news_outputs = generate(news_prompts)

# %%
aca_results = pd.DataFrame(aca_outputs, columns=['output'])
aca_results['prompt_category'] = 'ACA'
aca_results['prompt'] = aca_prompts

fic_results = pd.DataFrame(fic_outputs, columns=['output'])
fic_results['prompt_category'] = 'FIC'
fic_results['prompt'] = fic_prompts

news_results = pd.DataFrame(news_outputs, columns=['output'])
news_results['prompt_category'] = 'NEWS'
news_results['prompt'] = news_prompts

result_frames = [aca_results, fic_results, news_results]

result_df = pd.concat(result_frames, ignore_index=True)
result_df
# Out:
#                                                output prompt_category  \
# 0   The head then commented on his social developm...             ACA
# 1   Conclusions: Policy Rhetoric and Structural Re...             ACA
# 2   One advantage is the ability to model a range ...             ACA
# 3   These are culpable acts, often regarded as bei...             ACA
# 4   Genesis: An Authorship Study in Computer-assis...             ACA
# 5   One idea about the life habits of the dinosaur...             ACA
# 6   It is not in those circumstances surprising th...             ACA
# 7   In response to the e.m.f. (electromotive force...             ACA
# 8   The initial deformation corresponds to portion...             ACA
# 9   We illustrate reduction to upper Hessenberg fo...             ACA
# 10  The effects of humans can go far beyond this, ...             ACA
# 11  This much is social  democratic orthodoxy. But...             ACA
# 12  If the interviewee is very nervous it can help...             ACA
# 13  In many grammar books you will find a rule whi...             ACA
# 14  It should be obvious why a single structural o...             ACA
# 15  Apart from Wollen's historical and theoretical...             ACA
# 16  No doubt a finder of perishable commodities wo...             ACA
# 17  But it always seemed to me more important from...             ACA
# 18  This view, whereby science progresses through ...             ACA
# 19  A combined transformation In a recent paper, H...             ACA
# 20  Indeed,’ Corbett stirred, staring behind the n...             FIC
# 21  He was different from Owen. But then, Owen had...             FIC
# 22  She was overweight, overtired, distinctly anxi...             FIC
# 23  But unemployment didn't appeal to her. She had...             FIC
# 24  ‘But we leave tomorrow!’ she exclaimed.\n‘Well...             FIC
# 25  ‘Oh no,’ he said. ‘I’m a racist.’\nThe rhetori...             FIC
# 26  Paula smiled, enjoying her sister's discomfort...             FIC
# 27  Everywhere I hear about the malaise and uncert...             FIC
# 28  Hurry up with that tea there, Maggie!\nThe nam...             FIC
# 29  Merely perplexing, at times. But mostly... fun...             FIC
# 30  They've sold American rights in both of the no...             FIC
# 31  ‘Or more directly, dismiss the coypu man, keep...             FIC
# 32  Crowe and Anthea Warburton lay parallel, Anthe...             FIC
# 33  Wow!’ He gave her an admiring grin that was ve...             FIC
# 34  ‘The one at Porton Down has just the same safe...             FIC
# 35  How they always wanted to know what other men ...             FIC
# 36  They all spent time covering their asses. But ...             FIC
# 37  There was a link, too. But I couldn’t see it f...             FIC
# 38  The other was from the Vice President in charg...             FIC
# 39  ‘Oh !… Oh… But I couldn't…’ ‘What is it?’ Elin...             FIC
# 40  Mrs Cross flew back to Manchester yesterday to...            NEWS
# 41  Realising that she had not loved him, Boris th...            NEWS
# 42  TRIPS to Ireland recently have reinforced my v...            NEWS
# 43  Llanidloes finished on 127–9, in which Sean So...            NEWS
# 44  But it is essentially up to the patient.’ He s...            NEWS
# 45  Hammerson shot up 45p to 855p in sympathy.\nTh...            NEWS
# 46  As Fazzi Brothers is to Glasgow and the west o...            NEWS
# 47  Nasty man takes revenge, but stabs Lisa by mis...            NEWS
# 48  The discounts include 3pc off the standard loa...            NEWS
# 49  Eating Out: Plenty of places in all price rang...            NEWS
# 50  Accountants Touche Ross asked for an extension...            NEWS
# 51  In the coming year, he expects to borrow £50,0...            NEWS
# 52  These organisations include the Woodland Trust...            NEWS
# 53  Scanner appeal co-ordinator Jack Froggatt said...            NEWS
# 54  The shares plunged 18p to 266p on news that pr...            NEWS
# 55  The Picassos, according to Sotheby's valuer, w...            NEWS
# 56  Mr Hurd said delays in granting exit visas to ...            NEWS
# 57  Of course, I know perfectly well why the Depar...            NEWS
# 58  Jason, born eight minutes before his brother, ...            NEWS
# 59  ‘The people who are failing miserably are the ...            NEWS
#
#                                                prompt
# 0   The head then commented on his social developm...
# 1   Conclusions: Policy Rhetoric and Structural Re...
# 2   One advantage is the ability to model a range ...
# 3   These are culpable acts, often regarded as bei...
# 4   Genesis: An Authorship Study in Computer-assis...
# 5   One idea about the life habits of the dinosaur...
# 6   It is not in those circumstances surprising th...
# 7                           In response to the e.m.f.
# 8   The initial deformation corresponds to portion...
# 9   We illustrate reduction to upper Hessenberg fo...
# 10  The effects of humans can go far beyond this, ...
# 11         This much is social  democratic orthodoxy.
# 12  If the interviewee is very nervous it can help...
# 13  In many grammar books you will find a rule whi...
# 14  It should be obvious why a single structural o...
# 15  Apart from Wollen's historical and theoretical...
# 16  No doubt a finder of perishable commodities wo...
# 17  But it always seemed to me more important from...
# 18  This view, whereby science progresses through ...
# 19  A combined transformation In a recent paper, H...
# 20  Indeed,’ Corbett stirred, staring behind the n...
# 21                        He was different from Owen.
# 22  She was overweight, overtired, distinctly anxi...
# 23             But unemployment didn't appeal to her.
# 24            ‘But we leave tomorrow!’ she exclaimed.
# 25                                  ‘Oh no,’ he said.
# 26  Paula smiled, enjoying her sister's discomfort...
# 27  Everywhere I hear about the malaise and uncert...
# 28              Hurry up with that tea there, Maggie!
# 29                       Merely perplexing, at times.
# 30  They've sold American rights in both of the no...
# 31  ‘Or more directly, dismiss the coypu man, keep...
# 32  Crowe and Anthea Warburton lay parallel, Anthe...
# 33  Wow!’ He gave her an admiring grin that was ve...
# 34  ‘The one at Porton Down has just the same safe...
# 35  How they always wanted to know what other men ...
# 36          They all spent time covering their asses.
# 37                             There was a link, too.
# 38  The other was from the Vice President in charg...
# 39  ‘Oh !… Oh… But I couldn't…’ ‘What is it?’ Elin...
# 40  Mrs Cross flew back to Manchester yesterday to...
# 41  Realising that she had not loved him, Boris th...
# 42  TRIPS to Ireland recently have reinforced my v...
# 43  Llanidloes finished on 127–9, in which Sean So...
# 44  But it is essentially up to the patient.’ He s...
# 45         Hammerson shot up 45p to 855p in sympathy.
# 46  As Fazzi Brothers is to Glasgow and the west o...
# 47  Nasty man takes revenge, but stabs Lisa by mis...
# 48  The discounts include 3pc off the standard loa...
# 49  Eating Out: Plenty of places in all price rang...
# 50  Accountants Touche Ross asked for an extension...
# 51  In the coming year, he expects to borrow £50,0...
# 52  These organisations include the Woodland Trust...
# 53  Scanner appeal co-ordinator Jack Froggatt said...
# 54  The shares plunged 18p to 266p on news that pr...
# 55  The Picassos, according to Sotheby's valuer, w...
# 56  Mr Hurd said delays in granting exit visas to ...
# 57  Of course, I know perfectly well why the Depar...
# 58  Jason, born eight minutes before his brother, ...
# 59  ‘The people who are failing miserably are the ...

# %%
result_df.to_csv('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-news-output.csv', index=False)
