# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbauer1860/LDS_Project/blob/main/generation/generating_aca_2epoch_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This notebook references [the project of Salminen et al. (2021)](https://github.com/joolsa/FakeReviews/blob/)

# %%
# !pip install iteround -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 tensorboard huggingface_hub[cli] xformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 64.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 48.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 40.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 53.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 48.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.2 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Loading the model

# %% [markdown]
# Redownloading the model required some tweaks, which are described in:
# https://stackoverflow.com/questions/76459034/how-to-load-a-fine-tuned-peft-lora-model-based-on-llama-with-huggingface-transfo

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoTokenizer, AutoModelForCausalLM
from accelerate import infer_auto_device_map, init_empty_weights

peft_model_id = 'dbauer1860/llama-2-bnc-baby-academic-2-epochs'

config = PeftConfig.from_pretrained(peft_model_id)

model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    torch_dtype='auto',
    device_map='auto',
    offload_folder="offload", offload_state_dict = True
)
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]

# %% [markdown]
# # Extracting Word Counts and Prompts

# %%
import pandas as pd
import numpy as np
import random
import nltk
from iteround import saferound
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/bnc_baby_texts.csv', sep='|')

# %%
df.head()
# Out:
#                                                 text category
# 0  Why do certain images matter to one, and why i...      ACA
# 1  In many developing countries, the immunogenici...      ACA
# 2  Anthony Kenny The British Library 1992 Scholar...      ACA
# 3  Beforehand he worked as a probation officer fo...      ACA
# 4  CONTINUITY AND CHANGE are features of every po...      ACA

# %%
def split_into_sentences(text):
    return nltk.sent_tokenize(text)

# %%
df['sentences'] = df['text'].apply(split_into_sentences)

# %%
df
# Out:
#                                                   text category  \
# 0    Why do certain images matter to one, and why i...      ACA
# 1    In many developing countries, the immunogenici...      ACA
# 2    Anthony Kenny The British Library 1992 Scholar...      ACA
# 3    Beforehand he worked as a probation officer fo...      ACA
# 4    CONTINUITY AND CHANGE are features of every po...      ACA
# ..                                                 ...      ...
# 177  Artworks THE Friends of Oriel Ynys Mon, Llange...     NEWS
# 178  THERE will be those who portray the report of ...     NEWS
# 179  BUCKINGHAM PALACE 30 September: The Princess R...     NEWS
# 180  The Scottish Landowners' Federation unequivoca...     NEWS
# 181  An under-16s ladies soccer meeting will be hel...     NEWS
#
#                                              sentences
# 0    [Why do certain images matter to one, and why ...
# 1    [In many developing countries, the immunogenic...
# 2    [Anthony Kenny The British Library 1992 Schola...
# 3    [Beforehand he worked as a probation officer f...
# 4    [CONTINUITY AND CHANGE are features of every p...
# ..                                                 ...
# 177  [Artworks THE Friends of Oriel Ynys Mon, Llang...
# 178  [THERE will be those who portray the report of...
# 179  [BUCKINGHAM PALACE 30 September: The Princess ...
# 180  [The Scottish Landowners' Federation unequivoc...
# 181  [An under-16s ladies soccer meeting will be he...
#
# [182 rows x 3 columns]

# %%
random_state = 21
random_sentence_state = 21
sample_count = 20

# %%
def get_random_sentence(sentences_list, random_state=random_sentence_state, min_word_count=5):
    random.seed(random_state)
    filtered_sentences = [sentence for sentence in sentences_list if len(word_tokenize(sentence)) > min_word_count]
    return random.choice(filtered_sentences) if filtered_sentences else None

# %%
df['prompt'] = df['sentences'].apply(get_random_sentence)

# %%
def get_samples(df, n=sample_count, state=random_state):
  return df.sample(n=n, random_state=state)

# %%
df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]
# Out:
# <ipython-input-17-c993aa370679>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]

# %%
df_news
# Out:
#                                                   text category  \
# 95   This week's figures suggest that one in three ...     NEWS
# 116  It won the contract to build the power take-of...     NEWS
# 108  Opening with a tirade of four letter abuse fro...     NEWS
# 131  ‘What I have found in the region is that becau...     NEWS
# 124  Morning sickness good for mothers By Roger Hig...     NEWS
# 160  Interim figures unveiled yesterday show a 16% ...     NEWS
# 114  The baby is the accessory of the moment, seen ...     NEWS
# 149  THERE was confusion yesterday about the affect...     NEWS
# 98   EVERYONE who grew up in the Sixties has heard ...     NEWS
# 107  BIRMINGHAM'S infamous and exhausted retail hub...     NEWS
# 167  The day seemed very long yesterday. After givi...     NEWS
# 151  A Fish Association was duly set up under the c...     NEWS
# 147  These are the quiet days before winter. For mo...     NEWS
# 125  IT SEEMS that Roland Franklin, the latest unbu...     NEWS
# 119  DEAN REYNOLDS, whitewashed 10-0 by Steve Davis...     NEWS
# 104  THESE days, no one questions the importance of...     NEWS
# 86   One has to distinguish between the individual ...     NEWS
# 88   A SCANNING system developed by astronomers for...     NEWS
# 172  Sunbed scare… Could this machine damage your h...     NEWS
# 102  ‘Bucephala clangula’ sounds noisy but, in fact...     NEWS
#
#                                              sentences  \
# 95   [This week's figures suggest that one in three...
# 116  [It won the contract to build the power take-o...
# 108  [Opening with a tirade of four letter abuse fr...
# 131  [‘What I have found in the region is that beca...
# 124  [Morning sickness good for mothers By Roger Hi...
# 160  [Interim figures unveiled yesterday show a 16%...
# 114  [The baby is the accessory of the moment, seen...
# 149  [THERE was confusion yesterday about the affec...
# 98   [EVERYONE who grew up in the Sixties has heard...
# 107  [BIRMINGHAM'S infamous and exhausted retail hu...
# 167  [The day seemed very long yesterday., After gi...
# 151  [A Fish Association was duly set up under the ...
# 147  [These are the quiet days before winter., For ...
# 125  [IT SEEMS that Roland Franklin, the latest unb...
# 119  [DEAN REYNOLDS, whitewashed 10-0 by Steve Davi...
# 104  [THESE days, no one questions the importance o...
# 86   [One has to distinguish between the individual...
# 88   [A SCANNING system developed by astronomers fo...
# 172  [Sunbed scare… Could this machine damage your ...
# 102  [‘Bucephala clangula’ sounds noisy but, in fac...
#
#                                                 prompt
# 95   It is less ambiguous than the previous version...
# 116  Households in Wales spend most on tea, at 66p ...
# 108                      Details, tel Mrs Hartshorne .
# 131  They in turn work closely with local authoriti...
# 124  It involves nothing more than putting up 80-fo...
# 160  Here are 10 New Year resolutions to get you in...
# 114  Richard Holmes, the sales and marketing office...
# 149                      on the year at about 140,000.
# 98   The Maharishi Mahesh Yogi was a slickly-packag...
# 107  From this generous lobby, looked down on by di...
# 167                          ‘Vous souffrez toujours’.
# 151  ‘I've met him at a couple of PFA functions and...
# 147  They had sprouted from buried wood in the vege...
# 125  US airlines already find themselves at a disad...
# 119  ‘There are certain times that are better than ...
# 104  In spite of apparently incompatible personalit...
# 86   Europeans recognise that some individuals are ...
# 88   There is considerable evidence that starting o...
# 172  Tanning beds were introduced to reduce the ris...
# 102          They would not get away so lightly today.

# %%
aca_prompts = df_aca['prompt'].to_list()
fic_prompts = df_fic['prompt'].to_list()
news_prompts = df_news['prompt'].to_list()

# %% [markdown]
# # Generating output

# %%
#Generation parameters; these were, for the most part, set in accordance to Salminen et al.
#the only difference is the implementation of a deviation value
do_sample = True
top_k = 0
top_p = 0.92
temperature = 0.7
eos_token = model.config.eos_token_id
device = "cuda:0"
max_length = 1000

# %%
#from Salminen et al.; a seed value was set to allow the generation to be re-produced and continued over multiple sessions
def random_seed(seed_value, use_cuda):
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    random.seed(seed_value) # Python
    if use_cuda:
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# The generating loop

# %%
def generate(prompts):
  outputs = []
  for prompt in prompts:
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    random_seed(seed_value=random_state, use_cuda=True)
    o = model.generate(**inputs, do_sample=do_sample, top_k=top_k, top_p=top_p, temperature=temperature, eos_token_id=eos_token, max_length=max_length)
    outputs.append(tokenizer.decode(o[0], skip_special_tokens=True))
  return outputs

# %%
aca_outputs = generate(aca_prompts)

# %%
fic_outputs = generate(fic_prompts)

# %%
news_outputs = generate(news_prompts)

# %%
aca_results = pd.DataFrame(aca_outputs, columns=['output'])
aca_results['prompt_category'] = 'ACA'
aca_results['prompt'] = aca_prompts

fic_results = pd.DataFrame(fic_outputs, columns=['output'])
fic_results['prompt_category'] = 'FIC'
fic_results['prompt'] = fic_prompts

news_results = pd.DataFrame(news_outputs, columns=['output'])
news_results['prompt_category'] = 'NEWS'
news_results['prompt'] = news_prompts

result_frames = [aca_results, fic_results, news_results]

result_df = pd.concat(result_frames, ignore_index=True)
result_df
# Out:
#                                                output prompt_category  \
# 0   In general, the file designer will choose a bu...             ACA
# 1   The age distribution of a particular workforce...             ACA
# 2   Deixis has a powerful pragmatic base as most d...             ACA
# 3   9.8 Transport methods — vapour pressure osmome...             ACA
# 4   We have termed this system the ‘Leicester scor...             ACA
# 5   When this was applied to tissue sections, howe...             ACA
# 6   Inter-agency planning and collaboration The Un...             ACA
# 7   Our aim is first to determine the variation of...             ACA
# 8   In fact, it turns out that this solution can b...             ACA
# 9   A less elevated but similar claim was made by ...             ACA
# 10  Reference In presenting the traditional semant...             ACA
# 11  The various clones weave amongst and interming...             ACA
# 12  It is primarily her appearance, not the formal...             ACA
# 13  The guts of birds may contain seeds of more th...             ACA
# 14  If officers throw up their commissions and tro...             ACA
# 15  and add: the result is  (A) = 0.0096181.\n\nSo...             ACA
# 16  It is for cases of this kind, where the eviden...             ACA
# 17  (e)‘Political’ Differences in English Teaching...             ACA
# 18  The objections to poststructuralism at one lev...             ACA
# 19  Some US research groups appear to be tackling ...             ACA
# 20  The place was a powder keg. The tension was th...             FIC
# 21  Edward dropped the newspaper on to the carpet....             FIC
# 22  Immediately he tuned the set in, interference ...             FIC
# 23  ‘It was Nate himself who had the meetings fixe...             FIC
# 24  Ruth handed the letter to Ernest. 'It's from m...             FIC
# 25  Yorick drew his samurai sword and disembowelle...             FIC
# 26  The white Mercedes bus that had waited at the ...             FIC
# 27  Jump into the river!’ Behind him he heard Plac...             FIC
# 28  To name the whole earth with three nouns, that...             FIC
# 29  Time was when he was always around my house wi...             FIC
# 30  After a few months in jail for manslaughter, T...             FIC
# 31  Greg elbowed his way through and got behind th...             FIC
# 32  She looked, McLeish observed, as immaculate as...             FIC
# 33  Soon the place was alive with their busy whirr...             FIC
# 34  ‘I'll abort it for you, I can do it still with...             FIC
# 35  The brick side-wall of his neighbour's house s...             FIC
# 36  ‘An end to overcrowding, Miss Hopper,’ he said...             FIC
# 37  The English clerk would work doubly hard, eith...             FIC
# 38  Sammy was a competent skipper, but he could no...             FIC
# 39  All females in their thirties dressed like chi...             FIC
# 40  It is less ambiguous than the previous version...            NEWS
# 41  Households in Wales spend most on tea, at 66p ...            NEWS
# 42  Details, tel Mrs Hartshorne .\n39.181.071.109....            NEWS
# 43  They in turn work closely with local authoriti...            NEWS
# 44  It involves nothing more than putting up 80-fo...            NEWS
# 45  Here are 10 New Year resolutions to get you in...            NEWS
# 46  Richard Holmes, the sales and marketing office...            NEWS
# 47  on the year at about 140,000.\nIt is a stagger...            NEWS
# 48  The Maharishi Mahesh Yogi was a slickly-packag...            NEWS
# 49  From this generous lobby, looked down on by di...            NEWS
# 50  ‘Vous souffrez toujours’. C’est la réponse du ...            NEWS
# 51  ‘I've met him at a couple of PFA functions and...            NEWS
# 52  They had sprouted from buried wood in the vege...            NEWS
# 53  US airlines already find themselves at a disad...            NEWS
# 54  ‘There are certain times that are better than ...            NEWS
# 55  In spite of apparently incompatible personalit...            NEWS
# 56  Europeans recognise that some individuals are ...            NEWS
# 57  There is considerable evidence that starting o...            NEWS
# 58  Tanning beds were introduced to reduce the ris...            NEWS
# 59  They would not get away so lightly today.\nIt ...            NEWS
#
#                                                prompt
# 0   In general, the file designer will choose a bu...
# 1   The age distribution of a particular workforce...
# 2   Deixis has a powerful pragmatic base as most d...
# 3   9.8 Transport methods — vapour pressure osmome...
# 4   We have termed this system the ‘Leicester score’.
# 5   When this was applied to tissue sections, howe...
# 6   Inter-agency planning and collaboration The Un...
# 7   Our aim is first to determine the variation of...
# 8   In fact, it turns out that this solution can b...
# 9   A less elevated but similar claim was made by ...
# 10  Reference In presenting the traditional semant...
# 11  The various clones weave amongst and interming...
# 12  It is primarily her appearance, not the formal...
# 13  The guts of birds may contain seeds of more th...
# 14  If officers throw up their commissions and tro...
# 15                   and add: the result is  (A) = 0.
# 16  It is for cases of this kind, where the eviden...
# 17  (e)‘Political’ Differences in English Teaching...
# 18  The objections to poststructuralism at one lev...
# 19  Some US research groups appear to be tackling ...
# 20                        The place was a powder keg.
# 21     Edward dropped the newspaper on to the carpet.
# 22  Immediately he tuned the set in, interference ...
# 23  ‘It was Nate himself who had the meetings fixe...
# 24                  Ruth handed the letter to Ernest.
# 25  Yorick drew his samurai sword and disembowelle...
# 26  The white Mercedes bus that had waited at the ...
# 27  Jump into the river!’ Behind him he heard Plac...
# 28  To name the whole earth with three nouns, that...
# 29  Time was when he was always around my house wi...
# 30  After a few months in jail for manslaughter, T...
# 31  Greg elbowed his way through and got behind th...
# 32  She looked, McLeish observed, as immaculate as...
# 33  Soon the place was alive with their busy whirr...
# 34  ‘I'll abort it for you, I can do it still with...
# 35  The brick side-wall of his neighbour's house s...
# 36    ‘An end to overcrowding, Miss Hopper,’ he said.
# 37  The English clerk would work doubly hard, eith...
# 38  Sammy was a competent skipper, but he could no...
# 39  All females in their thirties dressed like chi...
# 40  It is less ambiguous than the previous version...
# 41  Households in Wales spend most on tea, at 66p ...
# 42                      Details, tel Mrs Hartshorne .
# 43  They in turn work closely with local authoriti...
# 44  It involves nothing more than putting up 80-fo...
# 45  Here are 10 New Year resolutions to get you in...
# 46  Richard Holmes, the sales and marketing office...
# 47                      on the year at about 140,000.
# 48  The Maharishi Mahesh Yogi was a slickly-packag...
# 49  From this generous lobby, looked down on by di...
# 50                          ‘Vous souffrez toujours’.
# 51  ‘I've met him at a couple of PFA functions and...
# 52  They had sprouted from buried wood in the vege...
# 53  US airlines already find themselves at a disad...
# 54  ‘There are certain times that are better than ...
# 55  In spite of apparently incompatible personalit...
# 56  Europeans recognise that some individuals are ...
# 57  There is considerable evidence that starting o...
# 58  Tanning beds were introduced to reduce the ris...
# 59          They would not get away so lightly today.

# %%
result_df.to_csv('/content/drive/MyDrive/Linguistic Data Science/data/2epoch-academic-output.csv', index=False)
