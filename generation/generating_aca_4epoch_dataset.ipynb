# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbauer1860/LDS_Project/blob/main/generation/generating_aca_4epoch_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This notebook references [the project of Salminen et al. (2021)](https://github.com/joolsa/FakeReviews/blob/)

# %%
# !pip install iteround -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 tensorboard huggingface_hub[cli] xformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 2.8 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Loading the model

# %% [markdown]
# Redownloading the model required some tweaks, which are described in:
# https://stackoverflow.com/questions/76459034/how-to-load-a-fine-tuned-peft-lora-model-based-on-llama-with-huggingface-transfo

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoTokenizer, AutoModelForCausalLM
from accelerate import infer_auto_device_map, init_empty_weights

peft_model_id = 'dbauer1860/llama-2-bnc-baby-academic-4-epochs'

config = PeftConfig.from_pretrained(peft_model_id)

model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    torch_dtype='auto',
    device_map='auto',
    offload_folder="offload", offload_state_dict = True
)
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]

# %% [markdown]
# # Extracting Word Counts and Prompts

# %%
import pandas as pd
import numpy as np
import random
import nltk
from iteround import saferound
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/bnc_baby_texts.csv', sep='|')

# %%
df.head()
# Out:
#                                                 text category
# 0  Why do certain images matter to one, and why i...      ACA
# 1  In many developing countries, the immunogenici...      ACA
# 2  Anthony Kenny The British Library 1992 Scholar...      ACA
# 3  Beforehand he worked as a probation officer fo...      ACA
# 4  CONTINUITY AND CHANGE are features of every po...      ACA

# %%
def split_into_sentences(text):
    return nltk.sent_tokenize(text)

# %%
df['sentences'] = df['text'].apply(split_into_sentences)

# %%
df
# Out:
#                                                   text category  \
# 0    Why do certain images matter to one, and why i...      ACA
# 1    In many developing countries, the immunogenici...      ACA
# 2    Anthony Kenny The British Library 1992 Scholar...      ACA
# 3    Beforehand he worked as a probation officer fo...      ACA
# 4    CONTINUITY AND CHANGE are features of every po...      ACA
# ..                                                 ...      ...
# 177  Artworks THE Friends of Oriel Ynys Mon, Llange...     NEWS
# 178  THERE will be those who portray the report of ...     NEWS
# 179  BUCKINGHAM PALACE 30 September: The Princess R...     NEWS
# 180  The Scottish Landowners' Federation unequivoca...     NEWS
# 181  An under-16s ladies soccer meeting will be hel...     NEWS
#
#                                              sentences
# 0    [Why do certain images matter to one, and why ...
# 1    [In many developing countries, the immunogenic...
# 2    [Anthony Kenny The British Library 1992 Schola...
# 3    [Beforehand he worked as a probation officer f...
# 4    [CONTINUITY AND CHANGE are features of every p...
# ..                                                 ...
# 177  [Artworks THE Friends of Oriel Ynys Mon, Llang...
# 178  [THERE will be those who portray the report of...
# 179  [BUCKINGHAM PALACE 30 September: The Princess ...
# 180  [The Scottish Landowners' Federation unequivoc...
# 181  [An under-16s ladies soccer meeting will be he...
#
# [182 rows x 3 columns]

# %%
random_state = 24
random_sentence_state = 1860
sample_count = 20

# %%
def get_random_sentence(sentences_list, random_state=random_sentence_state, min_word_count=5):
    random.seed(random_state)
    filtered_sentences = [sentence for sentence in sentences_list if len(word_tokenize(sentence)) > min_word_count]
    return random.choice(filtered_sentences) if filtered_sentences else None

# %%
df['prompt'] = df['sentences'].apply(get_random_sentence)

# %%
def get_samples(df, n=sample_count, state=random_state):
  return df.sample(n=n, random_state=state)

# %%
df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]
# Out:
# <ipython-input-16-c993aa370679>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]

# %%
df_news
# Out:
#                                                   text category  \
# 139  The team, yet to be named in full, will play t...     NEWS
# 174  CONFUSED shareholders have been seeking help o...     NEWS
# 109  IF THIS WAS HAPPINESS by Barbara Leaming, Weid...     NEWS
# 152  CANBERRA may seem an awful long way from excha...     NEWS
# 105  As vicar of Bidston and deeply involved in the...     NEWS
# 124  Morning sickness good for mothers By Roger Hig...     NEWS
# 142  The 18-year-old from North Shields beat off ei...     NEWS
# 170  The half-year course begins next month and off...     NEWS
# 116  It won the contract to build the power take-of...     NEWS
# 98   EVERYONE who grew up in the Sixties has heard ...     NEWS
# 123  West led the queen of clubs, and declarer won ...     NEWS
# 138  PRIZES will be awarded for the best carnations...     NEWS
# 168  JOHN BERRY, 54, who was released on parole las...     NEWS
# 169  NOVEMBER again. The shrinking of daylight, the...     NEWS
# 176  TEENAGERS facing the last two years of compuls...     NEWS
# 99   Vauxhall announced on May 28 that all 5,128 of...     NEWS
# 134  PETER FRASER, owner of the Classic Bookshop an...     NEWS
# 162  The guest house, in Stockbridge, is being orga...     NEWS
# 166  THE Conservatives sought last night to force t...     NEWS
# 135  According to local folklore the contractor, wh...     NEWS
#
#                                              sentences  \
# 139  [The team, yet to be named in full, will play ...
# 174  [CONFUSED shareholders have been seeking help ...
# 109  [IF THIS WAS HAPPINESS by Barbara Leaming, Wei...
# 152  [CANBERRA may seem an awful long way from exch...
# 105  [As vicar of Bidston and deeply involved in th...
# 124  [Morning sickness good for mothers By Roger Hi...
# 142  [The 18-year-old from North Shields beat off e...
# 170  [The half-year course begins next month and of...
# 116  [It won the contract to build the power take-o...
# 98   [EVERYONE who grew up in the Sixties has heard...
# 123  [West led the queen of clubs, and declarer won...
# 138  [PRIZES will be awarded for the best carnation...
# 168  [JOHN BERRY, 54, who was released on parole la...
# 169  [NOVEMBER again., The shrinking of daylight, t...
# 176  [TEENAGERS facing the last two years of compul...
# 99   [Vauxhall announced on May 28 that all 5,128 o...
# 134  [PETER FRASER, owner of the Classic Bookshop a...
# 162  [The guest house, in Stockbridge, is being org...
# 166  [THE Conservatives sought last night to force ...
# 135  [According to local folklore the contractor, w...
#
#                                                 prompt
# 139  Today Toyota are pinning their hopes on Phil S...
# 174  Profits of the Bisto-to-Mr-Kipling-cakes giant...
# 109  Realising that she had not loved him, Boris th...
# 152  However, it intends to retain the Hong Kong sh...
# 105  of Bootle Di can't know PRINCESS Diana knows n...
# 124  These organisations include the Woodland Trust...
# 142  Jason, born eight minutes before his brother, ...
# 170  DIESELS GO INTO OVERDRIVE The glass mystery: M...
# 116  If you read that the way you picked up a wine ...
# 98                   In fact, it was growing steadily.
# 123  The reason behind this concentrated specialist...
# 138  The revolution in glasshouses had surely start...
# 168                     Name badges are worn by staff.
# 169  There was a little humming and hah-ing and ‘No...
# 176  It is very complex, very grammatical, and the ...
# 99   Scanner appeal co-ordinator Jack Froggatt said...
# 134  The explosion in advertising space has not bee...
# 162  If you get sat on it is because you allow your...
# 166  Mr Hurd said delays in granting exit visas to ...
# 135  ‘When they told me the body had been mutilated...

# %%
aca_prompts = df_aca['prompt'].to_list()
fic_prompts = df_fic['prompt'].to_list()
news_prompts = df_news['prompt'].to_list()

# %% [markdown]
# # Generating output

# %%
#Generation parameters; these were, for the most part, set in accordance to Salminen et al.
#the only difference is the implementation of a deviation value
do_sample = True
top_k = 0
top_p = 0.92
temperature = 0.7
eos_token = model.config.eos_token_id
device = "cuda:0"
max_length = 1000
repetition_penalty = 1.1

# %%
#from Salminen et al.; a seed value was set to allow the generation to be re-produced and continued over multiple sessions
def random_seed(seed_value, use_cuda):
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    random.seed(seed_value) # Python
    if use_cuda:
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# The generating loop

# %%
def generate(prompts):
  outputs = []
  for prompt in prompts:
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    random_seed(seed_value=random_state, use_cuda=True)
    o = model.generate(**inputs, do_sample=do_sample, top_k=top_k, top_p=top_p, temperature=temperature, eos_token_id=eos_token, max_length=max_length, repetition_penalty=repetition_penalty)
    outputs.append(tokenizer.decode(o[0], skip_special_tokens=True))
  return outputs

# %%
aca_outputs = generate(aca_prompts)

# %%
fic_outputs = generate(fic_prompts)

# %%
news_outputs = generate(news_prompts)

# %%
aca_results = pd.DataFrame(aca_outputs, columns=['output'])
aca_results['prompt_category'] = 'ACA'
aca_results['prompt'] = aca_prompts

fic_results = pd.DataFrame(fic_outputs, columns=['output'])
fic_results['prompt_category'] = 'FIC'
fic_results['prompt'] = fic_prompts

news_results = pd.DataFrame(news_outputs, columns=['output'])
news_results['prompt_category'] = 'NEWS'
news_results['prompt'] = news_prompts

result_frames = [aca_results, fic_results, news_results]

result_df = pd.concat(result_frames, ignore_index=True)
result_df
# Out:
#                                                output prompt_category  \
# 0   The pressure here is to consider the sorts of ...             ACA
# 1   Conclusions: Policy Rhetoric and Structural Re...             ACA
# 2   There is also a connection between these two, ...             ACA
# 3   One advantage is the ability to model a range ...             ACA
# 4   But it always seemed to me more important from...             ACA
# 5   A combined transformation In a recent paper, H...             ACA
# 6   The effects of humans can go far beyond this, ...             ACA
# 7   Blocking will not usually increase the probabi...             ACA
# 8   The head then commented on his social developm...             ACA
# 9   We illustrate reduction to upper Hessenberg fo...             ACA
# 10  No doubt a finder of perishable commodities wo...             ACA
# 11  This view, whereby science progresses through ...             ACA
# 12  These are culpable acts, often regarded as bei...             ACA
# 13  However, while shoplifting occurred in the pas...             ACA
# 14  In response to the e.m.f. generated by a batte...             ACA
# 15  In many grammar books you will find a rule whi...             ACA
# 16  It should be obvious why a single structural o...             ACA
# 17  Those communities which did not receive franch...             ACA
# 18  The initial deformation corresponds to portion...             ACA
# 19  I was not prepared to travel 140 miles to and ...             ACA
# 20  Hurry up with that tea there, Maggie!\nThe Tor...             FIC
# 21  They've sold American rights in both of the no...             FIC
# 22  Crowe and Anthea Warburton lay parallel, Anthe...             FIC
# 23  The other was from the Vice President in charg...             FIC
# 24  Let's see how you manage to be Constable with ...             FIC
# 25  ‘Or more directly, dismiss the coypu man, keep...             FIC
# 26  ‘The one at Porton Down has just the same safe...             FIC
# 27  But unemployment didn't appeal to her. "I was ...             FIC
# 28  ‘But we leave tomorrow!’ she exclaimed. ‘You c...             FIC
# 29  ‘Well, you and Carol, you're sort of settled n...             FIC
# 30  How they always wanted to know what other men ...             FIC
# 31  Paula smiled, enjoying her sister's discomfort...             FIC
# 32  There was a link, too. I'd have to find it lat...             FIC
# 33  She was overweight, overtired, distinctly anxi...             FIC
# 34  They all spent time covering their asses.\nThe...             FIC
# 35  Everywhere I hear about the malaise and uncert...             FIC
# 36  Merely perplexing, at times.\nThe Wiggles is a...             FIC
# 37  He was different from Owen. He had a big mouth...             FIC
# 38  "I suppose so," Sara said, a little deflated. ...             FIC
# 39  ‘I think’, I said, trying to duck, ‘that you s...             FIC
# 40  Today Toyota are pinning their hopes on Phil S...            NEWS
# 41  Profits of the Bisto-to-Mr-Kipling-cakes giant...            NEWS
# 42  Realising that she had not loved him, Boris th...            NEWS
# 43  However, it intends to retain the Hong Kong sh...            NEWS
# 44  of Bootle Di can't know PRINCESS Diana knows n...            NEWS
# 45  These organisations include the Woodland Trust...            NEWS
# 46  Jason, born eight minutes before his brother, ...            NEWS
# 47  DIESELS GO INTO OVERDRIVE The glass mystery: M...            NEWS
# 48  If you read that the way you picked up a wine ...            NEWS
# 49  In fact, it was growing steadily.\nTheir first...            NEWS
# 50  The reason behind this concentrated specialist...            NEWS
# 51  The revolution in glasshouses had surely start...            NEWS
# 52  Name badges are worn by staff. These can be ch...            NEWS
# 53  There was a little humming and hah-ing and ‘No...            NEWS
# 54  It is very complex, very grammatical, and the ...            NEWS
# 55  Scanner appeal co-ordinator Jack Froggatt said...            NEWS
# 56  The explosion in advertising space has not bee...            NEWS
# 57  If you get sat on it is because you allow your...            NEWS
# 58  Mr Hurd said delays in granting exit visas to ...            NEWS
# 59  ‘When they told me the body had been mutilated...            NEWS
#
#                                                prompt
# 0   The pressure here is to consider the sorts of ...
# 1   Conclusions: Policy Rhetoric and Structural Re...
# 2   There is also a connection between these two, ...
# 3   One advantage is the ability to model a range ...
# 4   But it always seemed to me more important from...
# 5   A combined transformation In a recent paper, H...
# 6   The effects of humans can go far beyond this, ...
# 7   Blocking will not usually increase the probabi...
# 8   The head then commented on his social developm...
# 9   We illustrate reduction to upper Hessenberg fo...
# 10  No doubt a finder of perishable commodities wo...
# 11  This view, whereby science progresses through ...
# 12  These are culpable acts, often regarded as bei...
# 13  However, while shoplifting occurred in the pas...
# 14                          In response to the e.m.f.
# 15  In many grammar books you will find a rule whi...
# 16  It should be obvious why a single structural o...
# 17  Those communities which did not receive franch...
# 18  The initial deformation corresponds to portion...
# 19  I was not prepared to travel 140 miles to and ...
# 20              Hurry up with that tea there, Maggie!
# 21  They've sold American rights in both of the no...
# 22  Crowe and Anthea Warburton lay parallel, Anthe...
# 23  The other was from the Vice President in charg...
# 24  Let's see how you manage to be Constable with ...
# 25  ‘Or more directly, dismiss the coypu man, keep...
# 26  ‘The one at Porton Down has just the same safe...
# 27             But unemployment didn't appeal to her.
# 28            ‘But we leave tomorrow!’ she exclaimed.
# 29  ‘Well, you and Carol, you're sort of settled n...
# 30  How they always wanted to know what other men ...
# 31  Paula smiled, enjoying her sister's discomfort...
# 32                             There was a link, too.
# 33  She was overweight, overtired, distinctly anxi...
# 34          They all spent time covering their asses.
# 35  Everywhere I hear about the malaise and uncert...
# 36                       Merely perplexing, at times.
# 37                        He was different from Owen.
# 38      "I suppose so," Sara said, a little deflated.
# 39  ‘I think’, I said, trying to duck, ‘that you s...
# 40  Today Toyota are pinning their hopes on Phil S...
# 41  Profits of the Bisto-to-Mr-Kipling-cakes giant...
# 42  Realising that she had not loved him, Boris th...
# 43  However, it intends to retain the Hong Kong sh...
# 44  of Bootle Di can't know PRINCESS Diana knows n...
# 45  These organisations include the Woodland Trust...
# 46  Jason, born eight minutes before his brother, ...
# 47  DIESELS GO INTO OVERDRIVE The glass mystery: M...
# 48  If you read that the way you picked up a wine ...
# 49                  In fact, it was growing steadily.
# 50  The reason behind this concentrated specialist...
# 51  The revolution in glasshouses had surely start...
# 52                     Name badges are worn by staff.
# 53  There was a little humming and hah-ing and ‘No...
# 54  It is very complex, very grammatical, and the ...
# 55  Scanner appeal co-ordinator Jack Froggatt said...
# 56  The explosion in advertising space has not bee...
# 57  If you get sat on it is because you allow your...
# 58  Mr Hurd said delays in granting exit visas to ...
# 59  ‘When they told me the body had been mutilated...

# %%
result_df.to_csv('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-academic-output.csv', index=False, sep="|")
