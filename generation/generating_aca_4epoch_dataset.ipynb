# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbauer1860/LDS_Project/blob/main/generation/generating_aca_4epoch_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This notebook references [the project of Salminen et al. (2021)](https://github.com/joolsa/FakeReviews/blob/)

# %%
# !pip install iteround -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 tensorboard huggingface_hub[cli] xformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 47.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 27.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.3 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Loading the model

# %% [markdown]
# Redownloading the model required some tweaks, which are described in:
# https://stackoverflow.com/questions/76459034/how-to-load-a-fine-tuned-peft-lora-model-based-on-llama-with-huggingface-transfo

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoTokenizer, AutoModelForCausalLM
from accelerate import infer_auto_device_map, init_empty_weights

peft_model_id = 'dbauer1860/llama-2-bnc-baby-academic-4-epochs'

config = PeftConfig.from_pretrained(peft_model_id)

model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    torch_dtype='auto',
    device_map='auto',
    offload_folder="offload", offload_state_dict = True
)
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# adapter_config.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]

# %% [markdown]
# # Extracting Word Counts and Prompts

# %%
import pandas as pd
import numpy as np
import random
import nltk
from iteround import saferound
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/Linguistic Data Science/data/bnc_baby_texts.csv', sep='|')

# %%
df.head()
# Out:
#                                                 text category
# 0  Why do certain images matter to one, and why i...      ACA
# 1  In many developing countries, the immunogenici...      ACA
# 2  Anthony Kenny The British Library 1992 Scholar...      ACA
# 3  Beforehand he worked as a probation officer fo...      ACA
# 4  CONTINUITY AND CHANGE are features of every po...      ACA

# %%
def split_into_sentences(text):
    return nltk.sent_tokenize(text)

# %%
df['sentences'] = df['text'].apply(split_into_sentences)

# %%
df
# Out:
#                                                   text category  \
# 0    Why do certain images matter to one, and why i...      ACA
# 1    In many developing countries, the immunogenici...      ACA
# 2    Anthony Kenny The British Library 1992 Scholar...      ACA
# 3    Beforehand he worked as a probation officer fo...      ACA
# 4    CONTINUITY AND CHANGE are features of every po...      ACA
# ..                                                 ...      ...
# 177  Artworks THE Friends of Oriel Ynys Mon, Llange...     NEWS
# 178  THERE will be those who portray the report of ...     NEWS
# 179  BUCKINGHAM PALACE 30 September: The Princess R...     NEWS
# 180  The Scottish Landowners' Federation unequivoca...     NEWS
# 181  An under-16s ladies soccer meeting will be hel...     NEWS
#
#                                              sentences
# 0    [Why do certain images matter to one, and why ...
# 1    [In many developing countries, the immunogenic...
# 2    [Anthony Kenny The British Library 1992 Schola...
# 3    [Beforehand he worked as a probation officer f...
# 4    [CONTINUITY AND CHANGE are features of every p...
# ..                                                 ...
# 177  [Artworks THE Friends of Oriel Ynys Mon, Llang...
# 178  [THERE will be those who portray the report of...
# 179  [BUCKINGHAM PALACE 30 September: The Princess ...
# 180  [The Scottish Landowners' Federation unequivoc...
# 181  [An under-16s ladies soccer meeting will be he...
#
# [182 rows x 3 columns]

# %%
random_state = 24
random_sentence_state = 1860
sample_count = 20

# %%
def get_random_sentence(sentences_list, random_state=random_sentence_state, min_word_count=5):
    random.seed(random_state)
    filtered_sentences = [sentence for sentence in sentences_list if len(word_tokenize(sentence)) > min_word_count]
    return random.choice(filtered_sentences) if filtered_sentences else None

# %%
df['prompt'] = df['sentences'].apply(get_random_sentence)

# %%
def get_samples(df, n=sample_count, state=random_state):
  return df.sample(n=n, random_state=state)

# %%
df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]
# Out:
# <ipython-input-16-c993aa370679>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   df_aca, df_dem, df_fic, df_news = [get_samples(y) for x, y in df.groupby(['category'])]

# %%
df_news
# Out:
#                                                   text category  \
# 159  How to ensure a sympathetic reception for a ne...     NEWS
# 97   DENTISTS are pulling out patients' teeth unnec...     NEWS
# 115  THE ETHIOPIAN army is failing to halt northern...     NEWS
# 111  PUBLICANS in Wales are being shown ways of red...     NEWS
# 181  An under-16s ladies soccer meeting will be hel...     NEWS
# 107  BIRMINGHAM'S infamous and exhausted retail hub...     NEWS
# 136  I love it. Unashamedly, unrepentingly. Most pe...     NEWS
# 146  PERHAPS the Independent Traveller ought to car...     NEWS
# 127  Its two main slogans, repeated countless times...     NEWS
# 163  (November 28) was interesting for the assumpti...     NEWS
# 150  First the coach broke down. So three of the pu...     NEWS
# 153  We have had six products on the market for ove...     NEWS
# 87   Abandoned fawns have been reared on a bottle, ...     NEWS
# 168  JOHN BERRY, 54, who was released on parole las...     NEWS
# 122  WHEN I began practice at the Bar 25 years ago,...     NEWS
# 118  The main speaker will be Cefin Campbell, direc...     NEWS
# 172  Sunbed scare… Could this machine damage your h...     NEWS
# 85   What is the use of going to open beaches when ...     NEWS
# 120  Now the angry owner, whose home has been burgl...     NEWS
# 139  The team, yet to be named in full, will play t...     NEWS
#
#                                              sentences  \
# 159  [How to ensure a sympathetic reception for a n...
# 97   [DENTISTS are pulling out patients' teeth unne...
# 115  [THE ETHIOPIAN army is failing to halt norther...
# 111  [PUBLICANS in Wales are being shown ways of re...
# 181  [An under-16s ladies soccer meeting will be he...
# 107  [BIRMINGHAM'S infamous and exhausted retail hu...
# 136  [I love it., Unashamedly, unrepentingly., Most...
# 146  [PERHAPS the Independent Traveller ought to ca...
# 127  [Its two main slogans, repeated countless time...
# 163  [(November 28) was interesting for the assumpt...
# 150  [First the coach broke down., So three of the ...
# 153  [We have had six products on the market for ov...
# 87   [Abandoned fawns have been reared on a bottle,...
# 168  [JOHN BERRY, 54, who was released on parole la...
# 122  [WHEN I began practice at the Bar 25 years ago...
# 118  [The main speaker will be Cefin Campbell, dire...
# 172  [Sunbed scare… Could this machine damage your ...
# 85   [What is the use of going to open beaches when...
# 120  [Now the angry owner, whose home has been burg...
# 139  [The team, yet to be named in full, will play ...
#
#                                                 prompt
# 159  The text has been cut quite wantonly and only ...
# 97   Jean-Claude Kausmann doesn't get involved in l...
# 115  Prayers and protest over Chernobyl From EDWARD...
# 111  Visitors to the Pumphouse were invited to inpu...
# 181  Llanidloes finished on 127–9, in which Sean So...
# 107  Of course, I know perfectly well why the Depar...
# 136  They say they do not understand why their head...
# 146  Eating Out: Plenty of places in all price rang...
# 127  Two years on, the Intifada shows little sign o...
# 163  December 7, 1786: I am in a fair way of becomi...
# 150  ‘My players didn't freeze at Anfield, and I kn...
# 153  Of course, not all presents for the person-wit...
# 87   Treatment can cost anything from a few hundred...
# 168                     Name badges are worn by staff.
# 122  Their reactions can range from anger to irrati...
# 118  Tests will be carried out on up to 500 childre...
# 172  More than 500 staff and 450 GPs who are believ...
# 85   ‘I'm content to go into the army, and I'm defi...
# 120  Describing the track ‘as one of the most ancie...
# 139  Today Toyota are pinning their hopes on Phil S...

# %%
aca_prompts = df_aca['prompt'].to_list()
fic_prompts = df_fic['prompt'].to_list()
news_prompts = df_news['prompt'].to_list()

# %% [markdown]
# # Generating output

# %%
#Generation parameters; these were, for the most part, set in accordance to Salminen et al.
#the only difference is the implementation of a deviation value
do_sample = True
top_k = 0
top_p = 0.92
temperature = 0.7
eos_token = model.config.eos_token_id
device = "cuda:0"
max_length = 1000
repetition_penalty = 1.1

# %%
#from Salminen et al.; a seed value was set to allow the generation to be re-produced and continued over multiple sessions
def random_seed(seed_value, use_cuda):
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    random.seed(seed_value) # Python
    if use_cuda:
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# The generating loop

# %%
def generate(prompts):
  outputs = []
  for prompt in prompts:
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    random_seed(seed_value=random_state, use_cuda=True)
    o = model.generate(**inputs, do_sample=do_sample, top_k=top_k, top_p=top_p, temperature=temperature, eos_token_id=eos_token, max_length=max_length, repetition_penalty=repetition_penalty)
    outputs.append(tokenizer.decode(o[0], skip_special_tokens=True))
  return outputs

# %%
aca_outputs = generate(aca_prompts)

# %%
fic_outputs = generate(fic_prompts)

# %%
news_outputs = generate(news_prompts)

# %%
aca_results = pd.DataFrame(aca_outputs, columns=['output'])
aca_results['prompt_category'] = 'ACA'
aca_results['prompt'] = aca_prompts

fic_results = pd.DataFrame(fic_outputs, columns=['output'])
fic_results['prompt_category'] = 'FIC'
fic_results['prompt'] = fic_prompts

news_results = pd.DataFrame(news_outputs, columns=['output'])
news_results['prompt_category'] = 'NEWS'
news_results['prompt'] = news_prompts

result_frames = [aca_results, fic_results, news_results]

result_df = pd.concat(result_frames, ignore_index=True)
result_df
# Out:
#                                                output prompt_category  \
# 0   There is also a connection between these two, ...             ACA
# 1   No doubt a finder of perishable commodities wo...             ACA
# 2   A combined transformation In a recent paper, H...             ACA
# 3   The relation between high activity of TNF and ...             ACA
# 4   If the interviewee is very nervous it can help...             ACA
# 5   The head then commented on his social developm...             ACA
# 6   Its significance lies in the seriousness of th...             ACA
# 7   Blocking will not usually increase the probabi...             ACA
# 8   One idea about the life habits of the dinosaur...             ACA
# 9   It is not in those circumstances surprising th...             ACA
# 10  However, while shoplifting occurred in the pas...             ACA
# 11  Genesis: An Authorship Study in Computer-assis...             ACA
# 12  In response to the e.m.f. and its associated f...             ACA
# 13  In many grammar books you will find a rule whi...             ACA
# 14  The pressure here is to consider the sorts of ...             ACA
# 15  These are culpable acts, often regarded as bei...             ACA
# 16  We illustrate reduction to upper Hessenberg fo...             ACA
# 17  This view, whereby science progresses through ...             ACA
# 18  It should be obvious why a single structural o...             ACA
# 19  This much is social  democratic orthodoxy. But...             ACA
# 20  But unemployment didn't appeal to her. She wan...             FIC
# 21  Merely perplexing, at times.\nThe first time I...             FIC
# 22  ‘I think’, I said, trying to duck, ‘that you s...             FIC
# 23  Let's see how you manage to be Constable with ...             FIC
# 24  Hurry up with that tea there, Maggie!\nThe fir...             FIC
# 25  ‘Oh !… Oh… But I couldn't…’ ‘What is it?’ Elin...             FIC
# 26  The other was from the Vice President in charg...             FIC
# 27  She was overweight, overtired, distinctly anxi...             FIC
# 28  He was different from Owen. He didn't just loo...             FIC
# 29  How they always wanted to know what other men ...             FIC
# 30  ‘But we leave tomorrow!’ she exclaimed.\n‘That...             FIC
# 31  ‘Well, you and Carol, you're sort of settled n...             FIC
# 32  Indeed,’ Corbett stirred, staring behind the n...             FIC
# 33  Crowe and Anthea Warburton lay parallel, Anthe...             FIC
# 34  Wow!’ He gave her an admiring grin that was ve...             FIC
# 35  ‘The one at Porton Down has just the same safe...             FIC
# 36  Everywhere I hear about the malaise and uncert...             FIC
# 37  ‘Or more directly, dismiss the coypu man, keep...             FIC
# 38  There was a link, too.\nThe first time I saw h...             FIC
# 39  They've sold American rights in both of the no...             FIC
# 40  The text has been cut quite wantonly and only ...            NEWS
# 41  Jean-Claude Kausmann doesn't get involved in l...            NEWS
# 42  Prayers and protest over Chernobyl From EDWARD...            NEWS
# 43  Visitors to the Pumphouse were invited to inpu...            NEWS
# 44  Llanidloes finished on 127–9, in which Sean So...            NEWS
# 45  Of course, I know perfectly well why the Depar...            NEWS
# 46  They say they do not understand why their head...            NEWS
# 47  Eating Out: Plenty of places in all price rang...            NEWS
# 48  Two years on, the Intifada shows little sign o...            NEWS
# 49  December 7, 1786: I am in a fair way of becomi...            NEWS
# 50  ‘My players didn't freeze at Anfield, and I kn...            NEWS
# 51  Of course, not all presents for the person-wit...            NEWS
# 52  Treatment can cost anything from a few hundred...            NEWS
# 53  Name badges are worn by staff. These name badg...            NEWS
# 54  Their reactions can range from anger to irrati...            NEWS
# 55  Tests will be carried out on up to 500 childre...            NEWS
# 56  More than 500 staff and 450 GPs who are believ...            NEWS
# 57  ‘I'm content to go into the army, and I'm defi...            NEWS
# 58  Describing the track ‘as one of the most ancie...            NEWS
# 59  Today Toyota are pinning their hopes on Phil S...            NEWS
#
#                                                prompt
# 0   There is also a connection between these two, ...
# 1   No doubt a finder of perishable commodities wo...
# 2   A combined transformation In a recent paper, H...
# 3   The relation between high activity of TNF and ...
# 4   If the interviewee is very nervous it can help...
# 5   The head then commented on his social developm...
# 6   Its significance lies in the seriousness of th...
# 7   Blocking will not usually increase the probabi...
# 8   One idea about the life habits of the dinosaur...
# 9   It is not in those circumstances surprising th...
# 10  However, while shoplifting occurred in the pas...
# 11  Genesis: An Authorship Study in Computer-assis...
# 12                          In response to the e.m.f.
# 13  In many grammar books you will find a rule whi...
# 14  The pressure here is to consider the sorts of ...
# 15  These are culpable acts, often regarded as bei...
# 16  We illustrate reduction to upper Hessenberg fo...
# 17  This view, whereby science progresses through ...
# 18  It should be obvious why a single structural o...
# 19         This much is social  democratic orthodoxy.
# 20             But unemployment didn't appeal to her.
# 21                       Merely perplexing, at times.
# 22  ‘I think’, I said, trying to duck, ‘that you s...
# 23  Let's see how you manage to be Constable with ...
# 24              Hurry up with that tea there, Maggie!
# 25  ‘Oh !… Oh… But I couldn't…’ ‘What is it?’ Elin...
# 26  The other was from the Vice President in charg...
# 27  She was overweight, overtired, distinctly anxi...
# 28                        He was different from Owen.
# 29  How they always wanted to know what other men ...
# 30            ‘But we leave tomorrow!’ she exclaimed.
# 31  ‘Well, you and Carol, you're sort of settled n...
# 32  Indeed,’ Corbett stirred, staring behind the n...
# 33  Crowe and Anthea Warburton lay parallel, Anthe...
# 34  Wow!’ He gave her an admiring grin that was ve...
# 35  ‘The one at Porton Down has just the same safe...
# 36  Everywhere I hear about the malaise and uncert...
# 37  ‘Or more directly, dismiss the coypu man, keep...
# 38                             There was a link, too.
# 39  They've sold American rights in both of the no...
# 40  The text has been cut quite wantonly and only ...
# 41  Jean-Claude Kausmann doesn't get involved in l...
# 42  Prayers and protest over Chernobyl From EDWARD...
# 43  Visitors to the Pumphouse were invited to inpu...
# 44  Llanidloes finished on 127–9, in which Sean So...
# 45  Of course, I know perfectly well why the Depar...
# 46  They say they do not understand why their head...
# 47  Eating Out: Plenty of places in all price rang...
# 48  Two years on, the Intifada shows little sign o...
# 49  December 7, 1786: I am in a fair way of becomi...
# 50  ‘My players didn't freeze at Anfield, and I kn...
# 51  Of course, not all presents for the person-wit...
# 52  Treatment can cost anything from a few hundred...
# 53                     Name badges are worn by staff.
# 54  Their reactions can range from anger to irrati...
# 55  Tests will be carried out on up to 500 childre...
# 56  More than 500 staff and 450 GPs who are believ...
# 57  ‘I'm content to go into the army, and I'm defi...
# 58  Describing the track ‘as one of the most ancie...
# 59  Today Toyota are pinning their hopes on Phil S...

# %%
result_df.to_csv('/content/drive/MyDrive/Linguistic Data Science/data/4epoch-academic-output.csv', index=False, sep="|")
